# %%
import numpy

# %%
from collections import defaultdict
import xml.etree.ElementTree
import random

def load_data():
    prefix = "Fingerprint\\data\\"

    def load_filenames(filename):
        e = xml.etree.ElementTree.parse(prefix + filename).getroot()
        res = []
        print(e.find('fingerprints').keys())
        for fingerprint in list(e.find('fingerprints')):
            a = fingerprint.attrib
            res.append((a['file'], a['class']))
        return res

    def load_dataset(filelist):
        res = []
        graph_id = 0

        for fname, cls in filelist:
            e = xml.etree.ElementTree.parse(prefix + fname)
            graph = e.find('graph')

            nodes = dict()
            edges_connected_to_nodes = defaultdict(list)
            edge      = list()
            edge_info = dict()

            for child in list(graph):
                if child.tag == 'node':
                    node_id = child.attrib['id']
                    node_xy = [0, 0]
                    for node_attrib in list(child):
                        attrib_value = float(list(node_attrib)[0].text)

                        if node_attrib.attrib['name'] == 'x':
                            node_xy[0] = attrib_value
                        else:
                            node_xy[1] = attrib_value
                    nodes[node_id] = node_xy
                elif child.tag == 'edge':
                    edge_orient_angle = [0, 0]
                    for edge_attrib in list(child):
                        attrib_value = float(list(edge_attrib)[0].text)

                        if edge_attrib.attrib['name'] == 'orient':
                            edge_orient_angle[0] = attrib_value
                        elif edge_attrib.attrib['name'] == 'angle':
                            edge_orient_angle[1] = attrib_value

                    from_id = child.attrib['from']
                    to_id = child.attrib['to']
                    edge_weight = 1
                    edge_info[(from_id, to_id)] = [edge_weight ,edge_orient_angle]
                    edge.append((from_id, to_id))

            for node in nodes.keys():
                edges_connected_to_nodes[node] = ([], [])
                for item in edge:
                    if item[0] == node:  # outcome edge
                        edges_connected_to_nodes[node][0].append(item)
                    elif item[1] == node:  # income edge
                        edges_connected_to_nodes[node][1].append(item)

            if cls == "T":
                cls = "A"
            elif cls[0] == "T":
                cls = "A"
            else:
                cls = cls[0]

            if edges_connected_to_nodes:

                type = "Normal graph"

            else:

                type = "Empty graph"

            res.append((graph_id, nodes, edges_connected_to_nodes, edge_info, cls, type))
            graph_id += 1

        return res
    
    train_list = load_filenames('train.cxl')
    valid_list=load_filenames('valid.cxl')
    test_list=load_filenames('test.cxl')

    train_dataset = load_dataset(train_list)
    valid_dataset = load_dataset(valid_list)
    test_dataset = load_dataset(test_list)

    return train_dataset, valid_dataset, test_dataset

train, valid, test = load_data()
# Out:
# ['base', 'classmodel', 'count']
# ['base', 'classmodel', 'count']
# ['base', 'classmodel', 'count']

# %%
import math
from collections import Counter

ALPHA = 0.5
ALPHA_ = 1 - ALPHA


def compute_edge_cost(e1, e2,w_e1):
    absdiff = abs((e1 * w_e1)- e2)
    return min(absdiff, 2 * math.pi - absdiff)


def HEC(a_edges, b_edges,a_edges_info,b_edges_info,TAU_E):

    a_edges_in = a_edges[1]
    a_edges_out = a_edges[0]
    b_edges_in = b_edges[1]
    b_edges_out = b_edges[0]

    a_costs_in  =dict()
    a_costs_out =dict()

    for item in a_edges_in :

        a_costs_in[item] = ALPHA_  *  TAU_E * a_edges_info[item][0]

    for item in a_edges_out :
        a_costs_out[item] = ALPHA_  *  TAU_E * a_edges_info[item][0]

    b_costs_in = [ALPHA_ * TAU_E for _ in b_edges_in]
    b_costs_out = [ALPHA_ * TAU_E for _ in b_edges_out]


    for x in range(len(a_edges_in)):

        id_1=a_edges_in[x]
        for y in range(len(b_costs_in)):

            id_2=b_edges_in[y]
            edge_substitution_cost = ALPHA_ * compute_edge_cost(a_edges_info[id_1][1][1], b_edges_info[id_2][1][1],a_edges_info[id_1][0])
            a_costs_in[id_1] = min(a_costs_in[id_1], edge_substitution_cost / 2)
            b_costs_in[y] = min(b_costs_in[y], edge_substitution_cost / 2)


    for i in range(len(a_edges_out)):

        id_1 = a_edges_out[i]
        for j in range(len(b_costs_out)):

            id_2 = b_edges_out[j]
            edge_substitution_cost = ALPHA_ * compute_edge_cost(a_edges_info[id_1][1][1], b_edges_info[id_2][1][1],a_edges_info[id_1][0])
            a_costs_out[id_1] = min(a_costs_out[id_1], edge_substitution_cost / 2)
            b_costs_out[j] = min(b_costs_out[j], edge_substitution_cost / 2)

    return  sum_elem(a_costs_out) + sum_elem(a_costs_in) + sum(b_costs_in) + sum(b_costs_out)


def HED(g1, g2, TAU_E, TAU_N):

    g1_nodes, g1_edges ,g1_edges_info = g1[1], g1[2] ,g1[3]
    g2_nodes, g2_edges ,g2_edges_info = g2[1], g2[2] ,g2[3]

    g1_node_costs = []
    g2_node_costs = []

    g1_node_names = list(g1_nodes.keys())
    g2_node_names = list(g2_nodes.keys())


    for n in g1_node_names:
        cost = TAU_N * ALPHA
        for x in g1_edges[n] :
            for y in range(len(x)):
                cost += ALPHA_ * TAU_E / 2
        g1_node_costs.append(cost)

    for n in g2_node_names:
        cost = TAU_N * ALPHA
        for x in  g2_edges[n] :
            for y in range(len(x)):
                cost += ALPHA_ * TAU_E / 2
        g2_node_costs.append(cost)

    for i in range(len(g1_node_names)):
        degree_i =0

        edge_connected_to_node_i = g1_edges[g1_node_names[i]]
        for item in g1_edges[g1_node_names[i]] :
            for edge in item :
                degree_i += 1

        for j in range(len(g2_node_names)):
            degree_j = 0

            edge_connected_to_node_j = g2_edges[g2_node_names[j]]
            for item in g2_edges[g2_node_names[j]]:
                for edge in item:
                    degree_j += 1

            edge_substitution_cost = HEC(edge_connected_to_node_i,edge_connected_to_node_j,g1_edges_info, g2_edges_info ,TAU_E)
            edge_substitution_cost = max(edge_substitution_cost,abs(degree_i - degree_j) * TAU_E * ALPHA_)
            g1_node_costs[i] = min(g1_node_costs[i], (edge_substitution_cost / 4))
            g2_node_costs[j] = min(g2_node_costs[j], (edge_substitution_cost / 4))

    return max(sum(g1_node_costs) + sum(g2_node_costs), abs(len(g1_node_names) - len(g2_node_names)) * ALPHA * TAU_N)


from collections import defaultdict
def sum_elem(dict ):

    total =0
    for elem in dict.values():
        total +=elem

    return total

# %%
from sklearn.model_selection import ParameterGrid
import operator


def getNeighbors(trainingSet, Instance, k, TAU_E, TAU_N):
    distances = []
    neighbor  = []

    for x in range(len(trainingSet)):
        dist = HED(trainingSet[x], Instance, TAU_E, TAU_N)
        distances.append((trainingSet[x][-2], dist))

    distances.sort(key=operator.itemgetter(1))
    for x in range(k):
        neighbor.append(distances[x][0])

    return neighbor


def getResponse(neighbors):
    classVotes = {}
    for x in range(len(neighbors)):
        response = neighbors[x][0]
        if response in classVotes:
            classVotes[response] += 1
        else:
            classVotes[response] = 1
    sortedVotes = sorted(classVotes.items(), key=operator.itemgetter(1), reverse=True)
    return sortedVotes[0][0]


def getAccuracy(validSet, predictions):
    correct = 0
    for x in range(len(validSet)):
        if validSet[x][-2] == predictions[x]:
            correct += 1
    return (correct / float(len(validSet))) * 100


def find_optimal_params(train, valid):
    param_grid = {'TAU_E': [0.1, 0.4, 0.7, 1.0, 1.3, 1.6, 1.9, 2.2, 2.5, 10.0],
                  'TAU_N': [0.1, 0.4, 0.7, 1.0, 1.3, 1.6, 1.9, 2.2, 2.5, 10.0]
                  }

    grid = ParameterGrid(param_grid)

    best_hypers = None
    best_val = float('-inf')
    for params in grid:
        predictions = []
        for y in range(len(valid)):
            neighbors = getNeighbors(train, valid[y], k=1 , TAU_E=params['TAU_E'], TAU_N=params['TAU_N'])
            result = getResponse(neighbors)
            predictions.append(result)
        accuracy = getAccuracy(valid, predictions)
        if accuracy > best_val:
            best_val = accuracy
            best_hypers = params
    return best_hypers, best_val

# %%
train, valid, test = load_data()
dist = HED(train[13], train[22], TAU_E= 2.5 , TAU_N= 1.3)
dist
# Out:
# ['base', 'classmodel', 'count']
# ['base', 'classmodel', 'count']
# ['base', 'classmodel', 'count']
# 1.3032114133974482

# %%
train, valid, test = load_data()
train
# Out:
# ['base', 'classmodel', 'count']
# ['base', 'classmodel', 'count']
# ['base', 'classmodel', 'count']
# [(0, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (1, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (2, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (3, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (4, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (5, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (6, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (7, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (8, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (9, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (10, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (11, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (12, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (13,
#   {'_1': [62.0, 85.0],
#    '_2': [63.0, 87.0],
#    '_3': [93.0, 97.0],
#    '_4': [96.0, 99.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')]),
#                '_3': ([('_3', '_4')], [('_4', '_3')]),
#                '_4': ([('_4', '_3')], [('_3', '_4')])}),
#   {('_1', '_2'): [1, [0.894427, 1.107149]],
#    ('_2', '_1'): [1, [-0.894427, -2.034444]],
#    ('_3', '_4'): [1, [0.5547, 0.588003]],
#    ('_4', '_3'): [1, [-0.5547, -2.55359]]},
#   'A',
#   'Normal graph'),
#  (14, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (15, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (16, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (17,
#   {'_1': [150.0, 120.0], '_2': [155.0, 141.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.972806, 1.337053]],
#    ('_2', '_1'): [1, [-0.972806, -1.80454]]},
#   'A',
#   'Normal graph'),
#  (18,
#   {'_1': [36.0, 146.0],
#    '_2': [195.0, 147.0],
#    '_3': [30.0, 159.0],
#    '_4': [190.0, 161.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1')], [('_1', '_3')]),
#                '_4': ([('_4', '_2')], [('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.907959, 2.003204]],
#    ('_3', '_1'): [1, [-0.907959, -1.138389]],
#    ('_2', '_4'): [1, [0.941742, 1.91382]],
#    ('_4', '_2'): [1, [-0.941742, -1.227772]]},
#   'A',
#   'Normal graph'),
#  (19, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (20,
#   {'_1': [54.0, 145.0], '_2': [40.0, 167.0], '_3': [51.0, 157.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.970143, 1.815775]],
#    ('_3', '_1'): [1, [-0.970143, -1.325818]],
#    ('_3', '_2'): [1, [0.672673, 2.403778]],
#    ('_2', '_3'): [1, [-0.672673, -0.737815]]},
#   'A',
#   'Normal graph'),
#  (21, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (22,
#   {'_1': [39.0, 122.0],
#    '_2': [62.0, 137.0],
#    '_3': [65.0, 144.0],
#    '_4': [72.0, 161.0],
#    '_5': [56.0, 114.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_4')], [('_4', '_3')]),
#                '_4': ([('_4', '_3')], [('_3', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_2')],
#                 [('_1', '_5'), ('_2', '_5')])}),
#   {('_1', '_5'): [1, [-0.425797, -0.439843]],
#    ('_5', '_1'): [1, [0.425797, 2.70175]],
#    ('_5', '_2'): [1, [0.967617, 1.315614]],
#    ('_2', '_5'): [1, [-0.967617, -1.825979]],
#    ('_3', '_4'): [1, [0.924678, 1.180189]],
#    ('_4', '_3'): [1, [-0.924678, -1.961403]]},
#   'A',
#   'Normal graph'),
#  (23, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (24, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (25, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (26, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (27, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (28, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (29,
#   {'_1': [40.0, 51.0], '_2': [38.0, 62.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.98387, 1.75065]],
#    ('_2', '_1'): [1, [-0.98387, -1.390943]]},
#   'A',
#   'Normal graph'),
#  (30, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (31, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (32, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (33,
#   {'_1': [51.0, 41.0], '_2': [54.0, 50.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.948683, 1.249046]],
#    ('_2', '_1'): [1, [-0.948683, -1.892547]]},
#   'A',
#   'Normal graph'),
#  (34, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (35, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (36, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (37, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (38, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (39, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (40, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (41,
#   {'_1': [65.0, 45.0], '_2': [58.0, 55.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.819232, 2.181522]],
#    ('_2', '_1'): [1, [-0.819232, -0.96007]]},
#   'A',
#   'Normal graph'),
#  (42, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (43,
#   {'_1': [217.0, 112.0], '_2': [225.0, 134.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.939793, 1.222025]],
#    ('_2', '_1'): [1, [-0.939793, -1.919567]]},
#   'A',
#   'Normal graph'),
#  (44, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (45,
#   {'_1': [37.0, 118.0], '_2': [40.0, 120.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.5547, 0.588003]],
#    ('_2', '_1'): [1, [-0.5547, -2.55359]]},
#   'A',
#   'Normal graph'),
#  (46, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (47, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (48,
#   {'_1': [30.0, 106.0],
#    '_2': [78.0, 224.0],
#    '_3': [44.0, 111.0],
#    '_4': [55.0, 121.0],
#    '_5': [69.0, 127.0],
#    '_6': [79.0, 138.0],
#    '_7': [89.0, 149.0],
#    '_8': [97.0, 162.0],
#    '_9': [95.0, 179.0],
#    '_10': [86.0, 190.0],
#    '_11': [83.0, 208.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_11')], [('_11', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_10')],
#                 [('_8', '_9'), ('_10', '_9')]),
#                '_10': ([('_10', '_9'), ('_10', '_11')],
#                 [('_9', '_10'), ('_11', '_10')]),
#                '_11': ([('_11', '_10'), ('_11', '_2')],
#                 [('_10', '_11'), ('_2', '_11')])}),
#   {('_1', '_3'): [1, [0.336336, 0.343024]],
#    ('_3', '_1'): [1, [-0.336336, -2.798569]],
#    ('_3', '_4'): [1, [0.672673, 0.737815]],
#    ('_4', '_3'): [1, [-0.672673, -2.403778]],
#    ('_4', '_5'): [1, [0.393919, 0.404892]],
#    ('_5', '_4'): [1, [-0.393919, -2.736701]],
#    ('_5', '_6'): [1, [0.73994, 0.832981]],
#    ('_6', '_5'): [1, [-0.73994, -2.308611]],
#    ('_6', '_7'): [1, [0.73994, 0.832981]],
#    ('_7', '_6'): [1, [-0.73994, -2.308611]],
#    ('_7', '_8'): [1, [0.851658, 1.019141]],
#    ('_8', '_7'): [1, [-0.851658, -2.122451]],
#    ('_8', '_9'): [1, [0.993151, 1.687905]],
#    ('_9', '_8'): [1, [-0.993151, -1.453688]],
#    ('_9', '_10'): [1, [0.773957, 2.256526]],
#    ('_10', '_9'): [1, [-0.773957, -0.885067]],
#    ('_10', '_11'): [1, [0.986394, 1.735945]],
#    ('_11', '_10'): [1, [-0.986394, -1.405648]],
#    ('_11', '_2'): [1, [0.95448, 1.873681]],
#    ('_2', '_11'): [1, [-0.95448, -1.267911]]},
#   'A',
#   'Normal graph'),
#  (49, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (50, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (51, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (52, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (53, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (54, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (55,
#   {'_1': [47.0, 51.0],
#    '_2': [30.0, 58.0],
#    '_3': [70.0, 65.0],
#    '_4': [68.0, 84.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')]),
#                '_3': ([('_3', '_4')], [('_4', '_3')]),
#                '_4': ([('_4', '_3')], [('_3', '_4')])}),
#   {('_1', '_2'): [1, [0.38075, 2.750986]],
#    ('_2', '_1'): [1, [-0.38075, -0.390607]],
#    ('_3', '_4'): [1, [0.994505, 1.675673]],
#    ('_4', '_3'): [1, [-0.994505, -1.465919]]},
#   'A',
#   'Normal graph'),
#  (56, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (57, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (58, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (59, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (60, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (61, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (62,
#   {'_1': [212.0, 59.0],
#    '_2': [156.0, 111.0],
#    '_3': [222.0, 69.0],
#    '_4': [205.0, 72.0],
#    '_5': [206.0, 87.0],
#    '_6': [200.0, 101.0],
#    '_7': [186.0, 107.0],
#    '_8': [171.0, 112.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_8')], [('_8', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_2')],
#                 [('_7', '_8'), ('_2', '_8')])}),
#   {('_1', '_3'): [1, [0.707107, 0.785398]],
#    ('_3', '_1'): [1, [-0.707107, -2.356194]],
#    ('_3', '_4'): [1, [0.173785, 2.96692]],
#    ('_4', '_3'): [1, [-0.173785, -0.174672]],
#    ('_4', '_5'): [1, [0.997785, 1.504228]],
#    ('_5', '_4'): [1, [-0.997785, -1.637364]],
#    ('_5', '_6'): [1, [0.919145, 1.975688]],
#    ('_6', '_5'): [1, [-0.919145, -1.165905]],
#    ('_6', '_7'): [1, [0.393919, 2.736701]],
#    ('_7', '_6'): [1, [-0.393919, -0.404892]],
#    ('_7', '_8'): [1, [0.316228, 2.819842]],
#    ('_8', '_7'): [1, [-0.316228, -0.321751]],
#    ('_8', '_2'): [1, [-0.066519, -3.075024]],
#    ('_2', '_8'): [1, [0.066519, 0.066568]]},
#   'A',
#   'Normal graph'),
#  (63,
#   {'_1': [225.0, 142.0], '_2': [225.0, 152.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [1.0, 1.570796]], ('_2', '_1'): [1, [-1.0, -1.570796]]},
#   'A',
#   'Normal graph'),
#  (64, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (65, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (66,
#   {'_1': [64.0, 105.0],
#    '_2': [56.0, 106.0],
#    '_3': [58.0, 106.0],
#    '_4': [63.0, 106.0],
#    '_5': [58.0, 108.0],
#    '_6': [62.0, 110.0],
#    '_7': [83.0, 110.0],
#    '_8': [79.0, 117.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2'), ('_1', '_7'), ('_1', '_4')],
#                 [('_2', '_1'), ('_7', '_1'), ('_4', '_1')]),
#                '_2': ([('_2', '_1'), ('_2', '_3'), ('_2', '_5')],
#                 [('_1', '_2'), ('_3', '_2'), ('_5', '_2')]),
#                '_3': ([('_3', '_2'), ('_3', '_4'), ('_3', '_5')],
#                 [('_2', '_3'), ('_4', '_3'), ('_5', '_3')]),
#                '_4': ([('_4', '_1'), ('_4', '_3'), ('_4', '_6')],
#                 [('_1', '_4'), ('_3', '_4'), ('_6', '_4')]),
#                '_5': ([('_5', '_2'), ('_5', '_3'), ('_5', '_6')],
#                 [('_2', '_5'), ('_3', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_8'), ('_6', '_4'), ('_6', '_5')],
#                 [('_8', '_6'), ('_4', '_6'), ('_5', '_6')]),
#                '_7': ([('_7', '_1'), ('_7', '_8')],
#                 [('_1', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_6')],
#                 [('_7', '_8'), ('_6', '_8')])}),
#   {('_1', '_2'): [1, [0.124035, 3.017238]],
#    ('_2', '_1'): [1, [-0.124035, -0.124355]],
#    ('_1', '_7'): [1, [0.254493, 0.257324]],
#    ('_7', '_1'): [1, [-0.254493, -2.884269]],
#    ('_7', '_8'): [1, [0.868243, 2.089942]],
#    ('_8', '_7'): [1, [-0.868243, -1.05165]],
#    ('_8', '_6'): [1, [-0.38075, -2.750986]],
#    ('_6', '_8'): [1, [0.38075, 0.390607]],
#    ('_1', '_4'): [1, [0.707107, 2.356194]],
#    ('_4', '_1'): [1, [-0.707107, -0.785398]],
#    ('_2', '_3'): [1, [0.0, 0.0]],
#    ('_3', '_2'): [1, [0.0, 3.141593]],
#    ('_2', '_5'): [1, [0.707107, 0.785398]],
#    ('_5', '_2'): [1, [-0.707107, -2.356194]],
#    ('_3', '_4'): [1, [0.0, 0.0]],
#    ('_4', '_3'): [1, [0.0, 3.141593]],
#    ('_3', '_5'): [1, [1.0, 1.570796]],
#    ('_5', '_3'): [1, [-1.0, -1.570796]],
#    ('_4', '_6'): [1, [0.970143, 1.815775]],
#    ('_6', '_4'): [1, [-0.970143, -1.325818]],
#    ('_5', '_6'): [1, [0.447214, 0.463648]],
#    ('_6', '_5'): [1, [-0.447214, -2.677945]]},
#   'A',
#   'Normal graph'),
#  (67,
#   {'_1': [213.0, 57.0],
#    '_2': [224.0, 64.0],
#    '_3': [188.0, 84.0],
#    '_4': [165.0, 94.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')]),
#                '_3': ([('_3', '_4')], [('_4', '_3')]),
#                '_4': ([('_4', '_3')], [('_3', '_4')])}),
#   {('_1', '_2'): [1, [0.536875, 0.566729]],
#    ('_2', '_1'): [1, [-0.536875, -2.574863]],
#    ('_3', '_4'): [1, [0.398726, 2.731465]],
#    ('_4', '_3'): [1, [-0.398726, -0.410127]]},
#   'A',
#   'Normal graph'),
#  (68, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (69, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (70, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (71,
#   {'_1': [56.0, 141.0], '_2': [56.0, 173.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [1.0, 1.570796]], ('_2', '_1'): [1, [-1.0, -1.570796]]},
#   'A',
#   'Normal graph'),
#  (72, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (73, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (74, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (75, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (76, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (77, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (78,
#   {'_1': [35.0, 51.0], '_2': [30.0, 67.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.95448, 1.873681]],
#    ('_2', '_1'): [1, [-0.95448, -1.267911]]},
#   'A',
#   'Normal graph'),
#  (79,
#   {'_1': [225.0, 124.0], '_2': [216.0, 128.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.406138, 2.723368]],
#    ('_2', '_1'): [1, [-0.406138, -0.418224]]},
#   'A',
#   'Normal graph'),
#  (80,
#   {'_1': [221.0, 161.0], '_2': [217.0, 176.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.966235, 1.831399]],
#    ('_2', '_1'): [1, [-0.966235, -1.310194]]},
#   'A',
#   'Normal graph'),
#  (81,
#   {'_1': [121.0, 158.0],
#    '_2': [99.0, 192.0],
#    '_3': [114.0, 172.0],
#    '_4': [112.0, 184.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.894427, 2.034444]],
#    ('_3', '_1'): [1, [-0.894427, -1.107149]],
#    ('_3', '_4'): [1, [0.986394, 1.735945]],
#    ('_4', '_3'): [1, [-0.986394, -1.405648]],
#    ('_4', '_2'): [1, [0.524097, 2.589938]],
#    ('_2', '_4'): [1, [-0.524097, -0.551655]]},
#   'A',
#   'Normal graph'),
#  (82, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (83, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (84,
#   {'_1': [81.0, 115.0], '_2': [75.0, 122.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.759257, 2.279423]],
#    ('_2', '_1'): [1, [-0.759257, -0.86217]]},
#   'A',
#   'Normal graph'),
#  (85, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (86, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (87,
#   {'_1': [118.0, 130.0], '_2': [113.0, 154.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.97898, 1.776192]],
#    ('_2', '_1'): [1, [-0.97898, -1.365401]]},
#   'A',
#   'Normal graph'),
#  (88,
#   {'_1': [171.0, 160.0], '_2': [171.0, 165.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [1.0, 1.570796]], ('_2', '_1'): [1, [-1.0, -1.570796]]},
#   'A',
#   'Normal graph'),
#  (89, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (90, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (91, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (92, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (93, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (94,
#   {'_1': [68.0, 60.0],
#    '_2': [64.0, 87.0],
#    '_3': [80.0, 89.0],
#    '_4': [80.0, 108.0],
#    '_5': [62.0, 71.0],
#    '_6': [90.0, 100.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_6')], [('_6', '_3')]),
#                '_4': ([('_4', '_6')], [('_6', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_2')],
#                 [('_1', '_5'), ('_2', '_5')]),
#                '_6': ([('_6', '_3'), ('_6', '_4')],
#                 [('_3', '_6'), ('_4', '_6')])}),
#   {('_1', '_5'): [1, [0.877896, 2.070143]],
#    ('_5', '_1'): [1, [-0.877896, -1.07145]],
#    ('_5', '_2'): [1, [0.992278, 1.446441]],
#    ('_2', '_5'): [1, [-0.992278, -1.695151]],
#    ('_3', '_6'): [1, [0.73994, 0.832981]],
#    ('_6', '_3'): [1, [-0.73994, -2.308611]],
#    ('_6', '_4'): [1, [0.624695, 2.466852]],
#    ('_4', '_6'): [1, [-0.624695, -0.674741]]},
#   'A',
#   'Normal graph'),
#  (95, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (96, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (97, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (98,
#   {'_1': [136.0, 153.0], '_2': [135.0, 161.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.992278, 1.695151]],
#    ('_2', '_1'): [1, [-0.992278, -1.446441]]},
#   'A',
#   'Normal graph'),
#  (99,
#   {'_1': [162.0, 130.0],
#    '_2': [155.0, 184.0],
#    '_3': [158.0, 144.0],
#    '_4': [154.0, 163.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.961524, 1.849096]],
#    ('_3', '_1'): [1, [-0.961524, -1.292497]],
#    ('_3', '_4'): [1, [0.97855, 1.778293]],
#    ('_4', '_3'): [1, [-0.97855, -1.3633]],
#    ('_4', '_2'): [1, [0.998868, 1.523213]],
#    ('_2', '_4'): [1, [-0.998868, -1.618379]]},
#   'A',
#   'Normal graph'),
#  (100,
#   {'_1': [134.0, 112.0],
#    '_2': [129.0, 170.0],
#    '_3': [131.0, 131.0],
#    '_4': [128.0, 149.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.987763, 1.727398]],
#    ('_3', '_1'): [1, [-0.987763, -1.414194]],
#    ('_3', '_4'): [1, [0.986394, 1.735945]],
#    ('_4', '_3'): [1, [-0.986394, -1.405648]],
#    ('_4', '_2'): [1, [0.998868, 1.523213]],
#    ('_2', '_4'): [1, [-0.998868, -1.618379]]},
#   'A',
#   'Normal graph'),
#  (101,
#   {'_1': [141.0, 144.0], '_2': [149.0, 164.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.928477, 1.19029]],
#    ('_2', '_1'): [1, [-0.928477, -1.951303]]},
#   'A',
#   'Normal graph'),
#  (102,
#   {'_1': [143.0, 171.0], '_2': [140.0, 178.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.919145, 1.975688]],
#    ('_2', '_1'): [1, [-0.919145, -1.165905]]},
#   'A',
#   'Normal graph'),
#  (103, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (104,
#   {'_1': [138.0, 100.0],
#    '_2': [129.0, 176.0],
#    '_3': [130.0, 113.0],
#    '_4': [121.0, 124.0],
#    '_5': [121.0, 143.0],
#    '_6': [124.0, 160.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.851658, 2.122451]],
#    ('_3', '_1'): [1, [-0.851658, -1.019141]],
#    ('_3', '_4'): [1, [0.773957, 2.256526]],
#    ('_4', '_3'): [1, [-0.773957, -0.885067]],
#    ('_4', '_5'): [1, [1.0, 1.570796]],
#    ('_5', '_4'): [1, [-1.0, -1.570796]],
#    ('_5', '_6'): [1, [0.984784, 1.396124]],
#    ('_6', '_5'): [1, [-0.984784, -1.745469]],
#    ('_6', '_2'): [1, [0.95448, 1.267911]],
#    ('_2', '_6'): [1, [-0.95448, -1.873681]]},
#   'A',
#   'Normal graph'),
#  (105,
#   {'_1': [149.0, 102.0],
#    '_2': [151.0, 149.0],
#    '_3': [147.0, 116.0],
#    '_4': [146.0, 134.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.989949, 1.712693]],
#    ('_3', '_1'): [1, [-0.989949, -1.428899]],
#    ('_3', '_4'): [1, [0.99846, 1.626295]],
#    ('_4', '_3'): [1, [-0.99846, -1.515298]],
#    ('_4', '_2'): [1, [0.948683, 1.249046]],
#    ('_2', '_4'): [1, [-0.948683, -1.892547]]},
#   'A',
#   'Normal graph'),
#  (106, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (107,
#   {'_1': [147.0, 132.0], '_2': [140.0, 157.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.962964, 1.843805]],
#    ('_2', '_1'): [1, [-0.962964, -1.297788]]},
#   'A',
#   'Normal graph'),
#  (108,
#   {'_1': [117.0, 219.0], '_2': [109.0, 224.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.529999, 2.582993]],
#    ('_2', '_1'): [1, [-0.529999, -0.558599]]},
#   'A',
#   'Normal graph'),
#  (109,
#   {'_1': [124.0, 116.0], '_2': [120.0, 141.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.987441, 1.729452]],
#    ('_2', '_1'): [1, [-0.987441, -1.412141]]},
#   'A',
#   'Normal graph'),
#  (110,
#   {'_1': [129.0, 119.0], '_2': [124.0, 133.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.941742, 1.91382]],
#    ('_2', '_1'): [1, [-0.941742, -1.227772]]},
#   'A',
#   'Normal graph'),
#  (111, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (112,
#   {'_1': [30.0, 74.0],
#    '_2': [35.0, 100.0],
#    '_3': [145.0, 101.0],
#    '_4': [152.0, 158.0],
#    '_5': [39.0, 87.0],
#    '_6': [143.0, 122.0],
#    '_7': [150.0, 141.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_6')], [('_6', '_3')]),
#                '_4': ([('_4', '_7')], [('_7', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_2')],
#                 [('_1', '_5'), ('_2', '_5')]),
#                '_6': ([('_6', '_3'), ('_6', '_7')],
#                 [('_3', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_4')],
#                 [('_6', '_7'), ('_4', '_7')])}),
#   {('_1', '_5'): [1, [0.822192, 0.965252]],
#    ('_5', '_1'): [1, [-0.822192, -2.176341]],
#    ('_5', '_2'): [1, [0.955779, 1.869295]],
#    ('_2', '_5'): [1, [-0.955779, -1.272297]],
#    ('_3', '_6'): [1, [0.995495, 1.665748]],
#    ('_6', '_3'): [1, [-0.995495, -1.475845]],
#    ('_6', '_7'): [1, [0.938343, 1.217806]],
#    ('_7', '_6'): [1, [-0.938343, -1.923787]],
#    ('_7', '_4'): [1, [0.993151, 1.453688]],
#    ('_4', '_7'): [1, [-0.993151, -1.687905]]},
#   'A',
#   'Normal graph'),
#  (113,
#   {'_1': [134.0, 106.0], '_2': [130.0, 153.0], '_3': [131.0, 129.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.9916, 1.700499]],
#    ('_3', '_1'): [1, [-0.9916, -1.441094]],
#    ('_3', '_2'): [1, [0.999133, 1.612439]],
#    ('_2', '_3'): [1, [-0.999133, -1.529154]]},
#   'A',
#   'Normal graph'),
#  (114, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (115,
#   {'_1': [118.0, 90.0],
#    '_2': [119.0, 177.0],
#    '_3': [115.0, 106.0],
#    '_4': [108.0, 122.0],
#    '_5': [108.0, 142.0],
#    '_6': [114.0, 159.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.982872, 1.756144]],
#    ('_3', '_1'): [1, [-0.982872, -1.385448]],
#    ('_3', '_4'): [1, [0.916157, 1.983207]],
#    ('_4', '_3'): [1, [-0.916157, -1.158386]],
#    ('_4', '_5'): [1, [1.0, 1.570796]],
#    ('_5', '_4'): [1, [-1.0, -1.570796]],
#    ('_5', '_6'): [1, [0.94299, 1.231504]],
#    ('_6', '_5'): [1, [-0.94299, -1.910089]],
#    ('_6', '_2'): [1, [0.963518, 1.299849]],
#    ('_2', '_6'): [1, [-0.963518, -1.841743]]},
#   'A',
#   'Normal graph'),
#  (116,
#   {'_1': [48.0, 147.0],
#    '_2': [123.0, 156.0],
#    '_3': [62.0, 170.0],
#    '_4': [113.0, 179.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1')], [('_1', '_3')]),
#                '_4': ([('_4', '_2')], [('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.854199, 1.024007]],
#    ('_3', '_1'): [1, [-0.854199, -2.117585]],
#    ('_2', '_4'): [1, [0.91707, 1.980924]],
#    ('_4', '_2'): [1, [-0.91707, -1.160669]]},
#   'A',
#   'Normal graph'),
#  (117,
#   {'_1': [123.0, 104.0],
#    '_2': [123.0, 171.0],
#    '_3': [105.0, 101.0],
#    '_4': [110.0, 117.0],
#    '_5': [122.0, 128.0],
#    '_6': [131.0, 141.0],
#    '_7': [122.0, 153.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [-0.164399, -2.976444]],
#    ('_3', '_1'): [1, [0.164399, 0.165149]],
#    ('_3', '_4'): [1, [0.95448, 1.267911]],
#    ('_4', '_3'): [1, [-0.95448, -1.873681]],
#    ('_4', '_5'): [1, [0.675725, 0.741947]],
#    ('_5', '_4'): [1, [-0.675725, -2.399645]],
#    ('_5', '_6'): [1, [0.822192, 0.965252]],
#    ('_6', '_5'): [1, [-0.822192, -2.176341]],
#    ('_6', '_7'): [1, [0.8, 2.214297]],
#    ('_7', '_6'): [1, [-0.8, -0.927295]],
#    ('_7', '_2'): [1, [0.99846, 1.515298]],
#    ('_2', '_7'): [1, [-0.99846, -1.626295]]},
#   'A',
#   'Normal graph'),
#  (118,
#   {'_1': [96.0, 146.0], '_2': [89.0, 161.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.906183, 2.007423]],
#    ('_2', '_1'): [1, [-0.906183, -1.134169]]},
#   'A',
#   'Normal graph'),
#  (119,
#   {'_1': [137.0, 144.0], '_2': [142.0, 164.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.970143, 1.325818]],
#    ('_2', '_1'): [1, [-0.970143, -1.815775]]},
#   'A',
#   'Normal graph'),
#  (120,
#   {'_1': [57.0, 110.0],
#    '_2': [79.0, 121.0],
#    '_3': [87.0, 124.0],
#    '_4': [77.0, 129.0],
#    '_5': [91.0, 137.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')]),
#                '_3': ([('_3', '_5')], [('_5', '_3')]),
#                '_4': ([('_4', '_5')], [('_5', '_4')]),
#                '_5': ([('_5', '_3'), ('_5', '_4')],
#                 [('_3', '_5'), ('_4', '_5')])}),
#   {('_1', '_2'): [1, [0.447214, 0.463648]],
#    ('_2', '_1'): [1, [-0.447214, -2.677945]],
#    ('_3', '_5'): [1, [0.955779, 1.272297]],
#    ('_5', '_3'): [1, [-0.955779, -1.869295]],
#    ('_5', '_4'): [1, [-0.496139, -2.622447]],
#    ('_4', '_5'): [1, [0.496139, 0.519146]]},
#   'A',
#   'Normal graph'),
#  (121,
#   {'_1': [201.0, 122.0],
#    '_2': [170.0, 124.0],
#    '_3': [202.0, 137.0],
#    '_4': [169.0, 144.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1')], [('_1', '_3')]),
#                '_4': ([('_4', '_2')], [('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.997785, 1.504228]],
#    ('_3', '_1'): [1, [-0.997785, -1.637364]],
#    ('_2', '_4'): [1, [0.998752, 1.620755]],
#    ('_4', '_2'): [1, [-0.998752, -1.520838]]},
#   'A',
#   'Normal graph'),
#  (122,
#   {'_1': [126.0, 117.0],
#    '_2': [115.0, 163.0],
#    '_3': [120.0, 131.0],
#    '_4': [115.0, 147.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.919145, 1.975688]],
#    ('_3', '_1'): [1, [-0.919145, -1.165905]],
#    ('_3', '_4'): [1, [0.95448, 1.873681]],
#    ('_4', '_3'): [1, [-0.95448, -1.267911]],
#    ('_4', '_2'): [1, [1.0, 1.570796]],
#    ('_2', '_4'): [1, [-1.0, -1.570796]]},
#   'A',
#   'Normal graph'),
#  (123,
#   {'_1': [138.0, 147.0], '_2': [139.0, 156.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.993884, 1.460139]],
#    ('_2', '_1'): [1, [-0.993884, -1.681454]]},
#   'A',
#   'Normal graph'),
#  (124,
#   {'_1': [122.0, 132.0], '_2': [109.0, 152.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.838444, 2.147172]],
#    ('_2', '_1'): [1, [-0.838444, -0.994421]]},
#   'A',
#   'Normal graph'),
#  (125, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (126, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (127,
#   {'_1': [121.0, 118.0],
#    '_2': [130.0, 163.0],
#    '_3': [116.0, 133.0],
#    '_4': [123.0, 148.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.948683, 1.892547]],
#    ('_3', '_1'): [1, [-0.948683, -1.249046]],
#    ('_3', '_4'): [1, [0.906183, 1.134169]],
#    ('_4', '_3'): [1, [-0.906183, -2.007423]],
#    ('_4', '_2'): [1, [0.906183, 1.134169]],
#    ('_2', '_4'): [1, [-0.906183, -2.007423]]},
#   'A',
#   'Normal graph'),
#  (128,
#   {'_1': [108.0, 65.0],
#    '_2': [139.0, 166.0],
#    '_3': [100.0, 76.0],
#    '_4': [108.0, 90.0],
#    '_5': [113.0, 106.0],
#    '_6': [115.0, 126.0],
#    '_7': [125.0, 137.0],
#    '_8': [132.0, 152.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_8')], [('_8', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_2')],
#                 [('_7', '_8'), ('_2', '_8')])}),
#   {('_1', '_3'): [1, [0.808736, 2.199593]],
#    ('_3', '_1'): [1, [-0.808736, -0.942]],
#    ('_3', '_4'): [1, [0.868243, 1.05165]],
#    ('_4', '_3'): [1, [-0.868243, -2.089942]],
#    ('_4', '_5'): [1, [0.95448, 1.267911]],
#    ('_5', '_4'): [1, [-0.95448, -1.873681]],
#    ('_5', '_6'): [1, [0.995037, 1.471128]],
#    ('_6', '_5'): [1, [-0.995037, -1.670465]],
#    ('_6', '_7'): [1, [0.73994, 0.832981]],
#    ('_7', '_6'): [1, [-0.73994, -2.308611]],
#    ('_7', '_8'): [1, [0.906183, 1.134169]],
#    ('_8', '_7'): [1, [-0.906183, -2.007423]],
#    ('_8', '_2'): [1, [0.894427, 1.107149]],
#    ('_2', '_8'): [1, [-0.894427, -2.034444]]},
#   'A',
#   'Normal graph'),
#  (129,
#   {'_1': [41.0, 159.0], '_2': [50.0, 175.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.871576, 1.058407]],
#    ('_2', '_1'): [1, [-0.871576, -2.083186]]},
#   'A',
#   'Normal graph'),
#  (130,
#   {'_1': [127.0, 147.0], '_2': [126.0, 156.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.993884, 1.681454]],
#    ('_2', '_1'): [1, [-0.993884, -1.460139]]},
#   'A',
#   'Normal graph'),
#  (131,
#   {'_1': [148.0, 109.0], '_2': [144.0, 138.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.990621, 1.707863]],
#    ('_2', '_1'): [1, [-0.990621, -1.43373]]},
#   'A',
#   'Normal graph'),
#  (132,
#   {'_1': [97.0, 97.0], '_2': [96.0, 122.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.999201, 1.610775]],
#    ('_2', '_1'): [1, [-0.999201, -1.530818]]},
#   'A',
#   'Normal graph'),
#  (133, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (134, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (135, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (136,
#   {'_1': [156.0, 82.0],
#    '_2': [153.0, 158.0],
#    '_3': [156.0, 101.0],
#    '_4': [152.0, 118.0],
#    '_5': [152.0, 138.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [1.0, 1.570796]],
#    ('_3', '_1'): [1, [-1.0, -1.570796]],
#    ('_3', '_4'): [1, [0.973417, 1.801887]],
#    ('_4', '_3'): [1, [-0.973417, -1.339706]],
#    ('_4', '_5'): [1, [1.0, 1.570796]],
#    ('_5', '_4'): [1, [-1.0, -1.570796]],
#    ('_5', '_2'): [1, [0.998752, 1.520838]],
#    ('_2', '_5'): [1, [-0.998752, -1.620755]]},
#   'A',
#   'Normal graph'),
#  (137,
#   {'_1': [54.0, 133.0],
#    '_2': [57.0, 138.0],
#    '_3': [99.0, 139.0],
#    '_4': [125.0, 173.0],
#    '_5': [62.0, 120.0],
#    '_6': [74.0, 128.0],
#    '_7': [76.0, 137.0],
#    '_8': [94.0, 155.0],
#    '_9': [110.0, 163.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5'), ('_1', '_2')],
#                 [('_5', '_1'), ('_2', '_1')]),
#                '_2': ([('_2', '_7'), ('_2', '_1')],
#                 [('_7', '_2'), ('_1', '_2')]),
#                '_3': ([('_3', '_8')], [('_8', '_3')]),
#                '_4': ([('_4', '_9')], [('_9', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')]),
#                '_8': ([('_8', '_3'), ('_8', '_9')],
#                 [('_3', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_4')],
#                 [('_8', '_9'), ('_4', '_9')])}),
#   {('_1', '_5'): [1, [-0.851658, -1.019141]],
#    ('_5', '_1'): [1, [0.851658, 2.122451]],
#    ('_5', '_6'): [1, [0.5547, 0.588003]],
#    ('_6', '_5'): [1, [-0.5547, -2.55359]],
#    ('_6', '_7'): [1, [0.976187, 1.352127]],
#    ('_7', '_6'): [1, [-0.976187, -1.789465]],
#    ('_7', '_2'): [1, [0.052559, 3.08901]],
#    ('_2', '_7'): [1, [-0.052559, -0.052583]],
#    ('_1', '_2'): [1, [0.857493, 1.030377]],
#    ('_2', '_1'): [1, [-0.857493, -2.111216]],
#    ('_3', '_8'): [1, [0.95448, 1.873681]],
#    ('_8', '_3'): [1, [-0.95448, -1.267911]],
#    ('_8', '_9'): [1, [0.447214, 0.463648]],
#    ('_9', '_8'): [1, [-0.447214, -2.677945]],
#    ('_9', '_4'): [1, [0.5547, 0.588003]],
#    ('_4', '_9'): [1, [-0.5547, -2.55359]]},
#   'A',
#   'Normal graph'),
#  (138,
#   {'_1': [130.0, 121.0], '_2': [129.0, 133.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.996546, 1.653938]],
#    ('_2', '_1'): [1, [-0.996546, -1.487655]]},
#   'A',
#   'Normal graph'),
#  (139, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (140,
#   {'_1': [214.0, 124.0], '_2': [225.0, 140.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.824042, 0.968509]],
#    ('_2', '_1'): [1, [-0.824042, -2.173084]]},
#   'A',
#   'Normal graph'),
#  (141,
#   {'_1': [132.0, 132.0], '_2': [132.0, 154.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [1.0, 1.570796]], ('_2', '_1'): [1, [-1.0, -1.570796]]},
#   'A',
#   'Normal graph'),
#  (142,
#   {'_1': [119.0, 138.0],
#    '_2': [123.0, 190.0],
#    '_3': [116.0, 154.0],
#    '_4': [119.0, 173.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.982872, 1.756144]],
#    ('_3', '_1'): [1, [-0.982872, -1.385448]],
#    ('_3', '_4'): [1, [0.987763, 1.414194]],
#    ('_4', '_3'): [1, [-0.987763, -1.727398]],
#    ('_4', '_2'): [1, [0.973417, 1.339706]],
#    ('_2', '_4'): [1, [-0.973417, -1.801887]]},
#   'A',
#   'Normal graph'),
#  (143,
#   {'_1': [208.0, 93.0], '_2': [198.0, 102.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.668965, 2.408778]],
#    ('_2', '_1'): [1, [-0.668965, -0.732815]]},
#   'A',
#   'Normal graph'),
#  (144, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (145,
#   {'_1': [156.0, 150.0], '_2': [159.0, 171.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.989949, 1.428899]],
#    ('_2', '_1'): [1, [-0.989949, -1.712693]]},
#   'A',
#   'Normal graph'),
#  (146,
#   {'_1': [52.0, 74.0], '_2': [46.0, 87.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.907959, 2.003204]],
#    ('_2', '_1'): [1, [-0.907959, -1.138389]]},
#   'A',
#   'Normal graph'),
#  (147,
#   {'_1': [124.0, 150.0], '_2': [118.0, 156.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.707107, 2.356194]],
#    ('_2', '_1'): [1, [-0.707107, -0.785398]]},
#   'A',
#   'Normal graph'),
#  (148,
#   {'_1': [148.0, 151.0], '_2': [151.0, 162.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.964764, 1.304544]],
#    ('_2', '_1'): [1, [-0.964764, -1.837048]]},
#   'A',
#   'Normal graph'),
#  (149,
#   {'_1': [152.0, 139.0],
#    '_2': [144.0, 198.0],
#    '_3': [150.0, 159.0],
#    '_4': [147.0, 179.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.995037, 1.670465]],
#    ('_3', '_1'): [1, [-0.995037, -1.471128]],
#    ('_3', '_4'): [1, [0.988936, 1.719686]],
#    ('_4', '_3'): [1, [-0.988936, -1.421906]],
#    ('_4', '_2'): [1, [0.987763, 1.727398]],
#    ('_2', '_4'): [1, [-0.987763, -1.414194]]},
#   'A',
#   'Normal graph'),
#  (150,
#   {'_1': [56.0, 126.0],
#    '_2': [56.0, 127.0],
#    '_3': [112.0, 129.0],
#    '_4': [121.0, 183.0],
#    '_5': [115.0, 145.0],
#    '_6': [119.0, 166.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')]),
#                '_3': ([('_3', '_5')], [('_5', '_3')]),
#                '_4': ([('_4', '_6')], [('_6', '_4')]),
#                '_5': ([('_5', '_3'), ('_5', '_6')],
#                 [('_3', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_4')],
#                 [('_5', '_6'), ('_4', '_6')])}),
#   {('_1', '_2'): [1, [1.0, 1.570796]],
#    ('_2', '_1'): [1, [-1.0, -1.570796]],
#    ('_3', '_5'): [1, [0.982872, 1.385448]],
#    ('_5', '_3'): [1, [-0.982872, -1.756144]],
#    ('_5', '_6'): [1, [0.982339, 1.382575]],
#    ('_6', '_5'): [1, [-0.982339, -1.759018]],
#    ('_6', '_4'): [1, [0.993151, 1.453688]],
#    ('_4', '_6'): [1, [-0.993151, -1.687905]]},
#   'A',
#   'Normal graph'),
#  (151, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (152,
#   {'_1': [140.0, 160.0], '_2': [136.0, 170.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.928477, 1.951303]],
#    ('_2', '_1'): [1, [-0.928477, -1.19029]]},
#   'A',
#   'Normal graph'),
#  (153, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (154,
#   {'_1': [119.0, 95.0],
#    '_2': [107.0, 175.0],
#    '_3': [116.0, 108.0],
#    '_4': [107.0, 120.0],
#    '_5': [106.0, 139.0],
#    '_6': [107.0, 159.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.974391, 1.797595]],
#    ('_3', '_1'): [1, [-0.974391, -1.343997]],
#    ('_3', '_4'): [1, [0.8, 2.214297]],
#    ('_4', '_3'): [1, [-0.8, -0.927295]],
#    ('_4', '_5'): [1, [0.998618, 1.623379]],
#    ('_5', '_4'): [1, [-0.998618, -1.518213]],
#    ('_5', '_6'): [1, [0.998752, 1.520838]],
#    ('_6', '_5'): [1, [-0.998752, -1.620755]],
#    ('_6', '_2'): [1, [1.0, 1.570796]],
#    ('_2', '_6'): [1, [-1.0, -1.570796]]},
#   'A',
#   'Normal graph'),
#  (155,
#   {'_1': [143.0, 120.0], '_2': [143.0, 167.0], '_3': [140.0, 145.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.992877, 1.690225]],
#    ('_3', '_1'): [1, [-0.992877, -1.451367]],
#    ('_3', '_2'): [1, [0.99083, 1.435269]],
#    ('_2', '_3'): [1, [-0.99083, -1.706324]]},
#   'A',
#   'Normal graph'),
#  (156, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (157,
#   {'_1': [83.0, 119.0], '_2': [81.0, 136.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.993151, 1.687905]],
#    ('_2', '_1'): [1, [-0.993151, -1.453688]]},
#   'A',
#   'Normal graph'),
#  (158, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (159,
#   {'_1': [118.0, 125.0], '_2': [115.0, 133.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.936329, 1.929567]],
#    ('_2', '_1'): [1, [-0.936329, -1.212026]]},
#   'A',
#   'Normal graph'),
#  (160, {}, defaultdict(list, {}), {}, 'A', 'Empty graph'),
#  (161,
#   {'_1': [77.0, 72.0], '_2': [83.0, 100.0], '_3': [88.0, 85.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
# ...
#    ('_6', '_7'): [1, [0.963518, 1.299849]],
#    ('_7', '_6'): [1, [-0.963518, -1.841743]],
#    ('_7', '_2'): [1, [1.0, 1.570796]],
#    ('_2', '_7'): [1, [-1.0, -1.570796]]},
#   'R',
#   'Normal graph'),
#  (486,
#   {'_1': [153.0, 104.0],
#    '_2': [136.0, 174.0],
#    '_3': [155.0, 123.0],
#    '_4': [147.0, 139.0],
#    '_5': [142.0, 157.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [0.994505, 1.465919]],
#    ('_3', '_1'): [1, [-0.994505, -1.675673]],
#    ('_3', '_4'): [1, [0.894427, 2.034444]],
#    ('_4', '_3'): [1, [-0.894427, -1.107149]],
#    ('_4', '_5'): [1, [0.963518, 1.841743]],
#    ('_5', '_4'): [1, [-0.963518, -1.299849]],
#    ('_5', '_2'): [1, [0.94299, 1.910089]],
#    ('_2', '_5'): [1, [-0.94299, -1.231504]]},
#   'R',
#   'Normal graph'),
#  (487,
#   {'_1': [89.0, 184.0], '_2': [79.0, 204.0], '_3': [90.0, 194.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.995037, 1.471128]],
#    ('_3', '_1'): [1, [-0.995037, -1.670465]],
#    ('_3', '_2'): [1, [0.672673, 2.403778]],
#    ('_2', '_3'): [1, [-0.672673, -0.737815]]},
#   'R',
#   'Normal graph'),
#  (488,
#   {'_1': [111.0, 69.0],
#    '_2': [54.0, 113.0],
#    '_3': [63.0, 130.0],
#    '_4': [131.0, 142.0],
#    '_5': [105.0, 82.0],
#    '_6': [98.0, 96.0],
#    '_7': [114.0, 101.0],
#    '_8': [124.0, 111.0],
#    '_9': [129.0, 127.0],
#    '_10': [70.0, 105.0],
#    '_11': [81.0, 117.0],
#    '_12': [72.0, 130.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_10')], [('_10', '_2')]),
#                '_3': ([('_3', '_12')], [('_12', '_3')]),
#                '_4': ([('_4', '_9')], [('_9', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_4')],
#                 [('_8', '_9'), ('_4', '_9')]),
#                '_10': ([('_10', '_2'), ('_10', '_11')],
#                 [('_2', '_10'), ('_11', '_10')]),
#                '_11': ([('_11', '_10'), ('_11', '_12')],
#                 [('_10', '_11'), ('_12', '_11')]),
#                '_12': ([('_12', '_11'), ('_12', '_3')],
#                 [('_11', '_12'), ('_3', '_12')])}),
#   {('_1', '_5'): [1, [0.907959, 2.003204]],
#    ('_5', '_1'): [1, [-0.907959, -1.138389]],
#    ('_5', '_6'): [1, [0.894427, 2.034444]],
#    ('_6', '_5'): [1, [-0.894427, -1.107149]],
#    ('_6', '_7'): [1, [0.298275, 0.302885]],
#    ('_7', '_6'): [1, [-0.298275, -2.838708]],
#    ('_7', '_8'): [1, [0.707107, 0.785398]],
#    ('_8', '_7'): [1, [-0.707107, -2.356194]],
#    ('_8', '_9'): [1, [0.95448, 1.267911]],
#    ('_9', '_8'): [1, [-0.95448, -1.873681]],
#    ('_9', '_4'): [1, [0.991228, 1.438245]],
#    ('_4', '_9'): [1, [-0.991228, -1.703348]],
#    ('_2', '_10'): [1, [-0.447214, -0.463648]],
#    ('_10', '_2'): [1, [0.447214, 2.677945]],
#    ('_10', '_11'): [1, [0.737154, 0.828849]],
#    ('_11', '_10'): [1, [-0.737154, -2.312744]],
#    ('_11', '_12'): [1, [0.822192, 2.176341]],
#    ('_12', '_11'): [1, [-0.822192, -0.965252]],
#    ('_12', '_3'): [1, [0.0, 3.141593]],
#    ('_3', '_12'): [1, [0.0, 0.0]]},
#   'R',
#   'Normal graph'),
#  (489,
#   {'_1': [82.0, 97.0],
#    '_2': [71.0, 148.0],
#    '_3': [93.0, 109.0],
#    '_4': [78.0, 116.0],
#    '_5': [68.0, 129.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [0.737154, 0.828849]],
#    ('_3', '_1'): [1, [-0.737154, -2.312744]],
#    ('_3', '_4'): [1, [0.422885, 2.704965]],
#    ('_4', '_3'): [1, [-0.422885, -0.436627]],
#    ('_4', '_5'): [1, [0.792624, 2.226492]],
#    ('_5', '_4'): [1, [-0.792624, -0.915101]],
#    ('_5', '_2'): [1, [0.987763, 1.414194]],
#    ('_2', '_5'): [1, [-0.987763, -1.727398]]},
#   'R',
#   'Normal graph'),
#  (490,
#   {'_1': [118.0, 79.0],
#    '_2': [85.0, 145.0],
#    '_3': [112.0, 92.0],
#    '_4': [95.0, 97.0],
#    '_5': [82.0, 107.0],
#    '_6': [82.0, 127.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.907959, 2.003204]],
#    ('_3', '_1'): [1, [-0.907959, -1.138389]],
#    ('_3', '_4'): [1, [0.282166, 2.855541]],
#    ('_4', '_3'): [1, [-0.282166, -0.286051]],
#    ('_4', '_5'): [1, [0.609711, 2.485897]],
#    ('_5', '_4'): [1, [-0.609711, -0.655696]],
#    ('_5', '_6'): [1, [1.0, 1.570796]],
#    ('_6', '_5'): [1, [-1.0, -1.570796]],
#    ('_6', '_2'): [1, [0.986394, 1.405648]],
#    ('_2', '_6'): [1, [-0.986394, -1.735945]]},
#   'R',
#   'Normal graph'),
#  (491,
#   {'_1': [138.0, 117.0],
#    '_2': [65.0, 160.0],
#    '_3': [123.0, 125.0],
#    '_4': [105.0, 130.0],
#    '_5': [88.0, 137.0],
#    '_6': [73.0, 145.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.470588, 2.651635]],
#    ('_3', '_1'): [1, [-0.470588, -0.489957]],
#    ('_3', '_4'): [1, [0.267644, 2.870646]],
#    ('_4', '_3'): [1, [-0.267644, -0.270947]],
#    ('_4', '_5'): [1, [0.38075, 2.750986]],
#    ('_5', '_4'): [1, [-0.38075, -0.390607]],
#    ('_5', '_6'): [1, [0.470588, 2.651635]],
#    ('_6', '_5'): [1, [-0.470588, -0.489957]],
#    ('_6', '_2'): [1, [0.882353, 2.060754]],
#    ('_2', '_6'): [1, [-0.882353, -1.080839]]},
#   'R',
#   'Normal graph'),
#  (492,
#   {'_1': [96.0, 127.0],
#    '_2': [97.0, 127.0],
#    '_3': [103.0, 134.0],
#    '_4': [104.0, 134.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2'), ('_1', '_3')],
#                 [('_2', '_1'), ('_3', '_1')]),
#                '_2': ([('_2', '_1'), ('_2', '_4')],
#                 [('_1', '_2'), ('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_2'), ('_4', '_3')],
#                 [('_2', '_4'), ('_3', '_4')])}),
#   {('_1', '_2'): [1, [0.0, 0.0]],
#    ('_2', '_1'): [1, [0.0, 3.141593]],
#    ('_1', '_3'): [1, [0.707107, 0.785398]],
#    ('_3', '_1'): [1, [-0.707107, -2.356194]],
#    ('_2', '_4'): [1, [0.707107, 0.785398]],
#    ('_4', '_2'): [1, [-0.707107, -2.356194]],
#    ('_3', '_4'): [1, [0.0, 0.0]],
#    ('_4', '_3'): [1, [0.0, 3.141593]]},
#   'R',
#   'Normal graph'),
#  (493,
#   {'_1': [124.0, 101.0],
#    '_2': [219.0, 103.0],
#    '_3': [225.0, 123.0],
#    '_4': [120.0, 133.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_4')], [('_4', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_2')], [('_2', '_3')]),
#                '_4': ([('_4', '_1')], [('_1', '_4')])}),
#   {('_1', '_4'): [1, [0.992278, 1.695151]],
#    ('_4', '_1'): [1, [-0.992278, -1.446441]],
#    ('_2', '_3'): [1, [0.957826, 1.27934]],
#    ('_3', '_2'): [1, [-0.957826, -1.862253]]},
#   'R',
#   'Normal graph'),
#  (494,
#   {'_1': [119.0, 123.0],
#    '_2': [98.0, 174.0],
#    '_3': [106.0, 135.0],
#    '_4': [99.0, 154.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.67828, 2.396173]],
#    ('_3', '_1'): [1, [-0.67828, -0.745419]],
#    ('_3', '_4'): [1, [0.938343, 1.923787]],
#    ('_4', '_3'): [1, [-0.938343, -1.217806]],
#    ('_4', '_2'): [1, [0.998752, 1.620755]],
#    ('_2', '_4'): [1, [-0.998752, -1.520838]]},
#   'R',
#   'Normal graph'),
#  (495,
#   {'_1': [86.0, 128.0],
#    '_2': [85.0, 144.0],
#    '_3': [99.0, 150.0],
#    '_4': [89.0, 184.0],
#    '_5': [98.0, 121.0],
#    '_6': [107.0, 130.0],
#    '_7': [113.0, 143.0],
#    '_8': [101.0, 143.0],
#    '_9': [99.0, 167.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_8')], [('_8', '_2')]),
#                '_3': ([('_3', '_9')], [('_9', '_3')]),
#                '_4': ([('_4', '_9')], [('_9', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_2')],
#                 [('_7', '_8'), ('_2', '_8')]),
#                '_9': ([('_9', '_3'), ('_9', '_4')],
#                 [('_3', '_9'), ('_4', '_9')])}),
#   {('_1', '_5'): [1, [-0.503871, -0.528074]],
#    ('_5', '_1'): [1, [0.503871, 2.613518]],
#    ('_5', '_6'): [1, [0.707107, 0.785398]],
#    ('_6', '_5'): [1, [-0.707107, -2.356194]],
#    ('_6', '_7'): [1, [0.907959, 1.138389]],
#    ('_7', '_6'): [1, [-0.907959, -2.003204]],
#    ('_7', '_8'): [1, [0.0, 3.141593]],
#    ('_8', '_7'): [1, [0.0, 0.0]],
#    ('_8', '_2'): [1, [0.062378, 3.079174]],
#    ('_2', '_8'): [1, [-0.062378, -0.062419]],
#    ('_3', '_9'): [1, [1.0, 1.570796]],
#    ('_9', '_3'): [1, [-1.0, -1.570796]],
#    ('_9', '_4'): [1, [0.861934, 2.10252]],
#    ('_4', '_9'): [1, [-0.861934, -1.039072]]},
#   'R',
#   'Normal graph'),
#  (496,
#   {'_1': [123.0, 133.0],
#    '_2': [82.0, 168.0],
#    '_3': [112.0, 139.0],
#    '_4': [94.0, 139.0],
#    '_5': [85.0, 151.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [0.478852, 2.642246]],
#    ('_3', '_1'): [1, [-0.478852, -0.499347]],
#    ('_3', '_4'): [1, [0.0, 3.141593]],
#    ('_4', '_3'): [1, [0.0, 0.0]],
#    ('_4', '_5'): [1, [0.8, 2.214297]],
#    ('_5', '_4'): [1, [-0.8, -0.927295]],
#    ('_5', '_2'): [1, [0.984784, 1.745469]],
#    ('_2', '_5'): [1, [-0.984784, -1.396124]]},
#   'R',
#   'Normal graph'),
#  (497,
#   {'_1': [132.0, 119.0],
#    '_2': [40.0, 183.0],
#    '_3': [125.0, 131.0],
#    '_4': [110.0, 136.0],
#    '_5': [93.0, 140.0],
#    '_6': [79.0, 146.0],
#    '_7': [61.0, 149.0],
#    '_8': [48.0, 154.0],
#    '_9': [43.0, 166.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_9')], [('_9', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_2')],
#                 [('_8', '_9'), ('_2', '_9')])}),
#   {('_1', '_3'): [1, [0.863779, 2.098871]],
#    ('_3', '_1'): [1, [-0.863779, -1.042722]],
#    ('_3', '_4'): [1, [0.316228, 2.819842]],
#    ('_4', '_3'): [1, [-0.316228, -0.321751]],
#    ('_4', '_5'): [1, [0.229039, 2.910502]],
#    ('_5', '_4'): [1, [-0.229039, -0.231091]],
#    ('_5', '_6'): [1, [0.393919, 2.736701]],
#    ('_6', '_5'): [1, [-0.393919, -0.404892]],
#    ('_6', '_7'): [1, [0.164399, 2.976444]],
#    ('_7', '_6'): [1, [-0.164399, -0.165149]],
#    ('_7', '_8'): [1, [0.358979, 2.774419]],
#    ('_8', '_7'): [1, [-0.358979, -0.367174]],
#    ('_8', '_9'): [1, [0.923077, 1.965587]],
#    ('_9', '_8'): [1, [-0.923077, -1.176005]],
#    ('_9', '_2'): [1, [0.984784, 1.745469]],
#    ('_2', '_9'): [1, [-0.984784, -1.396124]]},
#   'R',
#   'Normal graph'),
#  (498,
#   {'_1': [135.0, 126.0], '_2': [123.0, 163.0], '_3': [126.0, 143.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.883788, 2.057696]],
#    ('_3', '_1'): [1, [-0.883788, -1.083897]],
#    ('_3', '_2'): [1, [0.988936, 1.719686]],
#    ('_2', '_3'): [1, [-0.988936, -1.421906]]},
#   'R',
#   'Normal graph'),
#  (499,
#   {'_1': [127.0, 108.0],
#    '_2': [69.0, 206.0],
#    '_3': [118.0, 119.0],
#    '_4': [101.0, 124.0],
#    '_5': [90.0, 135.0],
#    '_6': [72.0, 139.0],
#    '_7': [67.0, 154.0],
#    '_8': [66.0, 173.0],
#    '_9': [67.0, 192.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_9')], [('_9', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_2')],
#                 [('_8', '_9'), ('_2', '_9')])}),
#   {('_1', '_3'): [1, [0.773957, 2.256526]],
#    ('_3', '_1'): [1, [-0.773957, -0.885067]],
#    ('_3', '_4'): [1, [0.282166, 2.855541]],
#    ('_4', '_3'): [1, [-0.282166, -0.286051]],
#    ('_4', '_5'): [1, [0.707107, 2.356194]],
#    ('_5', '_4'): [1, [-0.707107, -0.785398]],
#    ('_5', '_6'): [1, [0.21693, 2.922924]],
#    ('_6', '_5'): [1, [-0.21693, -0.218669]],
#    ('_6', '_7'): [1, [0.948683, 1.892547]],
#    ('_7', '_6'): [1, [-0.948683, -1.249046]],
#    ('_7', '_8'): [1, [0.998618, 1.623379]],
#    ('_8', '_7'): [1, [-0.998618, -1.518213]],
#    ('_8', '_9'): [1, [0.998618, 1.518213]],
#    ('_9', '_8'): [1, [-0.998618, -1.623379]],
#    ('_9', '_2'): [1, [0.989949, 1.428899]],
#    ('_2', '_9'): [1, [-0.989949, -1.712693]]},
#   'R',
#   'Normal graph')]

# %%
train, valid, test = load_data()
params, accuracy   = find_optimal_params(train, valid)
# Out:
# ['base', 'classmodel', 'count']
# ['base', 'classmodel', 'count']
# ['base', 'classmodel', 'count']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [11], in <cell line: 2>()
#       1 train, valid, test = load_data()
# ----> 2 params, accuracy   = find_optimal_params(train, valid)
#
# Input In [10], in find_optimal_params(train, valid)
#      50 predictions = []
#      51 for y in range(len(valid)):
# ---> 52     neighbors = getNeighbors(train, valid[y], k=1 , TAU_E=params['TAU_E'], TAU_N=params['TAU_N'])
#      53     result = getResponse(neighbors)
#      54     predictions.append(result)
#
# Input In [10], in getNeighbors(trainingSet, Instance, k, TAU_E, TAU_N)
#       7 neighbor  = []
#       9 for x in range(len(trainingSet)):
# ---> 10     dist = HED(trainingSet[x], Instance, TAU_E, TAU_N)
#      11     distances.append((trainingSet[x][-2], dist))
#      13 distances.sort(key=operator.itemgetter(1))
#
# Input In [5], in HED(g1, g2, TAU_E, TAU_N)
#      97     for edge in item:
#      98         degree_j += 1
# --> 100 edge_substitution_cost = HEC(edge_connected_to_node_i,edge_connected_to_node_j,g1_edges_info, g2_edges_info ,TAU_E)
#     101 edge_substitution_cost = max(edge_substitution_cost,abs(degree_i - degree_j) * TAU_E * ALPHA_)
#     102 g1_node_costs[i] = min(g1_node_costs[i], (edge_substitution_cost / 4))
#
# Input In [5], in HEC(a_edges, b_edges, a_edges_info, b_edges_info, TAU_E)
#      21 a_costs_out =dict()
#      23 for item in a_edges_in :
# ---> 25     a_costs_in[item] = ALPHA_  *  TAU_E * a_edges_info[item][0]
#      27 for item in a_edges_out :
#      28     a_costs_out[item] = ALPHA_  *  TAU_E * a_edges_info[item][0]
#
# KeyboardInterrupt:

# %% [markdown]
# params

# %%
accuracy
# Out:
# 84.0

# %%
import pickle

def read_chunk(name):    
    
    with open(name, 'rb') as fp:
        data = pickle.load(fp)       
        
    return data

# %%
import time
train, valid, test = load_data()
tr=read_chunk('final-chunk-2')
predictions = []

start = time.time()
for x in range(len(test)):
    neighbors = getNeighbors(tr, test[x], k=1 , TAU_E= 2.2 , TAU_N= 1.3)
    result = getResponse(neighbors)
    predictions.append(result)
    #print('> predicted=' + repr(result) + ', actual=' + repr(test[x][-2]))

accuracy = getAccuracy(test, predictions)
print('Accuracy: ' + repr(accuracy) + ' %')
stop = time.time()
#print("Time: {:.1f}".format((stop-start))+' seconds')
# Out:
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# Accuracy: 80.60000000000001 %

# %%
a=0
w=0
l=0
r=0

for graph in train:
    if graph[-2 ]=='A' :
        a+=1
    elif graph[-2 ]=='L' :
        l+=1
    elif graph[-2 ]=='W' :
        w+=1  
    elif graph[-2 ]=='R' :
        r+=1

# %%
a
# Out:
# 198

# %%
w
# Out:
# 88

# %%
r
# Out:
# 92

# %%
l
# Out:
# 122

# %%
train, valid, test = load_data()
# Out:
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:36: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
# C:\Users\VAIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: DeprecationWarning: This method will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.

# %%
train[286:408]
# Out:
# [(286,
#   {'_1': [147.0, 125.0], '_2': [171.0, 140.0], '_3': [158.0, 142.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.83957, 0.996491]],
#    ('_3', '_1'): [1, [-0.83957, -2.145101]],
#    ('_3', '_2'): [1, [-0.152057, -0.152649]],
#    ('_2', '_3'): [1, [0.152057, 2.988943]]},
#   'L',
#   'Normal graph'),
#  (287,
#   {'_1': [149.0, 115.0],
#    '_2': [193.0, 191.0],
#    '_3': [161.0, 126.0],
#    '_4': [173.0, 136.0],
#    '_5': [186.0, 146.0],
#    '_6': [200.0, 155.0],
#    '_7': [197.0, 172.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.675725, 0.741947]],
#    ('_3', '_1'): [1, [-0.675725, -2.399645]],
#    ('_3', '_4'): [1, [0.640184, 0.694738]],
#    ('_4', '_3'): [1, [-0.640184, -2.446854]],
#    ('_4', '_5'): [1, [0.609711, 0.655696]],
#    ('_5', '_4'): [1, [-0.609711, -2.485897]],
#    ('_5', '_6'): [1, [0.540758, 0.571337]],
#    ('_6', '_5'): [1, [-0.540758, -2.570255]],
#    ('_6', '_7'): [1, [0.984784, 1.745469]],
#    ('_7', '_6'): [1, [-0.984784, -1.396124]],
#    ('_7', '_2'): [1, [0.97855, 1.778293]],
#    ('_2', '_7'): [1, [-0.97855, -1.3633]]},
#   'L',
#   'Normal graph'),
#  (288,
#   {'_1': [135.0, 120.0], '_2': [153.0, 157.0], '_3': [145.0, 138.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.874157, 1.063698]],
#    ('_3', '_1'): [1, [-0.874157, -2.077895]],
#    ('_3', '_2'): [1, [0.921635, 1.172274]],
#    ('_2', '_3'): [1, [-0.921635, -1.969319]]},
#   'L',
#   'Normal graph'),
#  (289,
#   {'_1': [123.0, 149.0],
#    '_2': [193.0, 187.0],
#    '_3': [139.0, 155.0],
#    '_4': [154.0, 161.0],
#    '_5': [170.0, 167.0],
#    '_6': [183.0, 175.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.351123, 0.358771]],
#    ('_3', '_1'): [1, [-0.351123, -2.782822]],
#    ('_3', '_4'): [1, [0.371391, 0.380506]],
#    ('_4', '_3'): [1, [-0.371391, -2.761086]],
#    ('_4', '_5'): [1, [0.351123, 0.358771]],
#    ('_5', '_4'): [1, [-0.351123, -2.782822]],
#    ('_5', '_6'): [1, [0.524097, 0.551655]],
#    ('_6', '_5'): [1, [-0.524097, -2.589938]],
#    ('_6', '_2'): [1, [0.768221, 0.876058]],
#    ('_2', '_6'): [1, [-0.768221, -2.265535]]},
#   'L',
#   'Normal graph'),
#  (290,
#   {'_1': [132.0, 99.0],
#    '_2': [200.0, 159.0],
#    '_3': [139.0, 113.0],
#    '_4': [155.0, 119.0],
#    '_5': [165.0, 130.0],
#    '_6': [177.0, 139.0],
#    '_7': [192.0, 146.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.894427, 1.107149]],
#    ('_3', '_1'): [1, [-0.894427, -2.034444]],
#    ('_3', '_4'): [1, [0.351123, 0.358771]],
#    ('_4', '_3'): [1, [-0.351123, -2.782822]],
#    ('_4', '_5'): [1, [0.73994, 0.832981]],
#    ('_5', '_4'): [1, [-0.73994, -2.308611]],
#    ('_5', '_6'): [1, [0.6, 0.643501]],
#    ('_6', '_5'): [1, [-0.6, -2.498092]],
#    ('_6', '_7'): [1, [0.422885, 0.436627]],
#    ('_7', '_6'): [1, [-0.422885, -2.704965]],
#    ('_7', '_2'): [1, [0.851658, 1.019141]],
#    ('_2', '_7'): [1, [-0.851658, -2.122451]]},
#   'L',
#   'Normal graph'),
#  (291,
#   {'_1': [133.0, 102.0],
#    '_2': [195.0, 183.0],
#    '_3': [139.0, 116.0],
#    '_4': [158.0, 114.0],
#    '_5': [175.0, 117.0],
#    '_6': [185.0, 128.0],
#    '_7': [197.0, 136.0],
#    '_8': [202.0, 151.0],
#    '_9': [196.0, 166.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_9')], [('_9', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_2')],
#                 [('_8', '_9'), ('_2', '_9')])}),
#   {('_1', '_3'): [1, [0.919145, 1.165905]],
#    ('_3', '_1'): [1, [-0.919145, -1.975688]],
#    ('_3', '_4'): [1, [-0.104685, -0.104877]],
#    ('_4', '_3'): [1, [0.104685, 3.036716]],
#    ('_4', '_5'): [1, [0.173785, 0.174672]],
#    ('_5', '_4'): [1, [-0.173785, -2.96692]],
#    ('_5', '_6'): [1, [0.73994, 0.832981]],
#    ('_6', '_5'): [1, [-0.73994, -2.308611]],
#    ('_6', '_7'): [1, [0.5547, 0.588003]],
#    ('_7', '_6'): [1, [-0.5547, -2.55359]],
#    ('_7', '_8'): [1, [0.948683, 1.249046]],
#    ('_8', '_7'): [1, [-0.948683, -1.892547]],
#    ('_8', '_9'): [1, [0.928477, 1.951303]],
#    ('_9', '_8'): [1, [-0.928477, -1.19029]],
#    ('_9', '_2'): [1, [0.998274, 1.629552]],
#    ('_2', '_9'): [1, [-0.998274, -1.512041]]},
#   'L',
#   'Normal graph'),
#  (292,
#   {'_1': [44.0, 52.0],
#    '_2': [32.0, 55.0],
#    '_3': [150.0, 75.0],
#    '_4': [165.0, 112.0],
#    '_5': [154.0, 90.0],
#    '_6': [165.0, 99.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')]),
#                '_3': ([('_3', '_5')], [('_5', '_3')]),
#                '_4': ([('_4', '_6')], [('_6', '_4')]),
#                '_5': ([('_5', '_3'), ('_5', '_6')],
#                 [('_3', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_4')],
#                 [('_5', '_6'), ('_4', '_6')])}),
#   {('_1', '_2'): [1, [0.242536, 2.896614]],
#    ('_2', '_1'): [1, [-0.242536, -0.244979]],
#    ('_3', '_5'): [1, [0.966235, 1.310194]],
#    ('_5', '_3'): [1, [-0.966235, -1.831399]],
#    ('_5', '_6'): [1, [0.633238, 0.68573]],
#    ('_6', '_5'): [1, [-0.633238, -2.455863]],
#    ('_6', '_4'): [1, [1.0, 1.570796]],
#    ('_4', '_6'): [1, [-1.0, -1.570796]]},
#   'L',
#   'Normal graph'),
#  (293,
#   {'_1': [154.0, 93.0],
#    '_2': [176.0, 128.0],
#    '_3': [195.0, 139.0],
#    '_4': [199.0, 161.0],
#    '_5': [163.0, 105.0],
#    '_6': [174.0, 115.0],
#    '_7': [185.0, 124.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_4')], [('_4', '_3')]),
#                '_4': ([('_4', '_3')], [('_3', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_5'): [1, [0.8, 0.927295]],
#    ('_5', '_1'): [1, [-0.8, -2.214297]],
#    ('_5', '_6'): [1, [0.672673, 0.737815]],
#    ('_6', '_5'): [1, [-0.672673, -2.403778]],
#    ('_6', '_7'): [1, [0.633238, 0.68573]],
#    ('_7', '_6'): [1, [-0.633238, -2.455863]],
#    ('_7', '_2'): [1, [0.406138, 2.723368]],
#    ('_2', '_7'): [1, [-0.406138, -0.418224]],
#    ('_3', '_4'): [1, [0.98387, 1.390943]],
#    ('_4', '_3'): [1, [-0.98387, -1.75065]]},
#   'L',
#   'Normal graph'),
#  (294,
#   {'_1': [114.0, 106.0],
#    '_2': [162.0, 190.0],
#    '_3': [126.0, 116.0],
#    '_4': [138.0, 127.0],
#    '_5': [146.0, 141.0],
#    '_6': [153.0, 156.0],
#    '_7': [155.0, 175.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.640184, 0.694738]],
#    ('_3', '_1'): [1, [-0.640184, -2.446854]],
#    ('_3', '_4'): [1, [0.675725, 0.741947]],
#    ('_4', '_3'): [1, [-0.675725, -2.399645]],
#    ('_4', '_5'): [1, [0.868243, 1.05165]],
#    ('_5', '_4'): [1, [-0.868243, -2.089942]],
#    ('_5', '_6'): [1, [0.906183, 1.134169]],
#    ('_6', '_5'): [1, [-0.906183, -2.007423]],
#    ('_6', '_7'): [1, [0.994505, 1.465919]],
#    ('_7', '_6'): [1, [-0.994505, -1.675673]],
#    ('_7', '_2'): [1, [0.906183, 1.134169]],
#    ('_2', '_7'): [1, [-0.906183, -2.007423]]},
#   'L',
#   'Normal graph'),
#  (295,
#   {'_1': [138.0, 168.0], '_2': [140.0, 176.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.970143, 1.325818]],
#    ('_2', '_1'): [1, [-0.970143, -1.815775]]},
#   'L',
#   'Normal graph'),
#  (296,
#   {'_1': [140.0, 129.0],
#    '_2': [215.0, 163.0],
#    '_3': [148.0, 116.0],
#    '_4': [161.0, 112.0],
#    '_5': [173.0, 121.0],
#    '_6': [188.0, 127.0],
#    '_7': [200.0, 136.0],
#    '_8': [209.0, 148.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_8')], [('_8', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_2')],
#                 [('_7', '_8'), ('_2', '_8')])}),
#   {('_1', '_3'): [1, [-0.851658, -1.019141]],
#    ('_3', '_1'): [1, [0.851658, 2.122451]],
#    ('_3', '_4'): [1, [-0.294086, -0.298499]],
#    ('_4', '_3'): [1, [0.294086, 2.843094]],
#    ('_4', '_5'): [1, [0.6, 0.643501]],
#    ('_5', '_4'): [1, [-0.6, -2.498092]],
#    ('_5', '_6'): [1, [0.371391, 0.380506]],
#    ('_6', '_5'): [1, [-0.371391, -2.761086]],
#    ('_6', '_7'): [1, [0.6, 0.643501]],
#    ('_7', '_6'): [1, [-0.6, -2.498092]],
#    ('_7', '_8'): [1, [0.8, 0.927295]],
#    ('_8', '_7'): [1, [-0.8, -2.214297]],
#    ('_8', '_2'): [1, [0.928477, 1.19029]],
#    ('_2', '_8'): [1, [-0.928477, -1.951303]]},
#   'L',
#   'Normal graph'),
#  (297,
#   {'_1': [163.0, 126.0],
#    '_2': [183.0, 166.0],
#    '_3': [170.0, 139.0],
#    '_4': [180.0, 149.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.880471, 1.076855]],
#    ('_3', '_1'): [1, [-0.880471, -2.064738]],
#    ('_3', '_4'): [1, [0.707107, 0.785398]],
#    ('_4', '_3'): [1, [-0.707107, -2.356194]],
#    ('_4', '_2'): [1, [0.984784, 1.396124]],
#    ('_2', '_4'): [1, [-0.984784, -1.745469]]},
#   'L',
#   'Normal graph'),
#  (298,
#   {'_1': [161.0, 180.0], '_2': [161.0, 191.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [1.0, 1.570796]], ('_2', '_1'): [1, [-1.0, -1.570796]]},
#   'L',
#   'Normal graph'),
#  (299,
#   {'_1': [130.0, 88.0], '_2': [160.0, 112.0], '_3': [142.0, 103.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.780869, 0.896055]],
#    ('_3', '_1'): [1, [-0.780869, -2.245537]],
#    ('_3', '_2'): [1, [0.447214, 0.463648]],
#    ('_2', '_3'): [1, [-0.447214, -2.677945]]},
#   'L',
#   'Normal graph'),
#  (300, {}, defaultdict(list, {}), {}, 'L', 'Empty graph'),
#  (301,
#   {'_1': [129.0, 119.0],
#    '_2': [170.0, 184.0],
#    '_3': [142.0, 127.0],
#    '_4': [160.0, 130.0],
#    '_5': [168.0, 144.0],
#    '_6': [169.0, 164.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.524097, 0.551655]],
#    ('_3', '_1'): [1, [-0.524097, -2.589938]],
#    ('_3', '_4'): [1, [0.164399, 0.165149]],
#    ('_4', '_3'): [1, [-0.164399, -2.976444]],
#    ('_4', '_5'): [1, [0.868243, 1.05165]],
#    ('_5', '_4'): [1, [-0.868243, -2.089942]],
#    ('_5', '_6'): [1, [0.998752, 1.520838]],
#    ('_6', '_5'): [1, [-0.998752, -1.620755]],
#    ('_6', '_2'): [1, [0.998752, 1.520838]],
#    ('_2', '_6'): [1, [-0.998752, -1.620755]]},
#   'L',
#   'Normal graph'),
#  (302,
#   {'_1': [114.0, 136.0], '_2': [133.0, 160.0], '_3': [126.0, 146.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.640184, 0.694738]],
#    ('_3', '_1'): [1, [-0.640184, -2.446854]],
#    ('_3', '_2'): [1, [0.894427, 1.107149]],
#    ('_2', '_3'): [1, [-0.894427, -2.034444]]},
#   'L',
#   'Normal graph'),
#  (303,
#   {'_1': [161.0, 79.0],
#    '_2': [225.0, 133.0],
#    '_3': [225.0, 150.0],
#    '_4': [225.0, 169.0],
#    '_5': [170.0, 88.0],
#    '_6': [185.0, 93.0],
#    '_7': [196.0, 102.0],
#    '_8': [207.0, 111.0],
#    '_9': [212.0, 126.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_9')], [('_9', '_2')]),
#                '_3': ([('_3', '_4')], [('_4', '_3')]),
#                '_4': ([('_4', '_3')], [('_3', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_2')],
#                 [('_8', '_9'), ('_2', '_9')])}),
#   {('_1', '_5'): [1, [0.707107, 0.785398]],
#    ('_5', '_1'): [1, [-0.707107, -2.356194]],
#    ('_5', '_6'): [1, [0.316228, 0.321751]],
#    ('_6', '_5'): [1, [-0.316228, -2.819842]],
#    ('_6', '_7'): [1, [0.633238, 0.68573]],
#    ('_7', '_6'): [1, [-0.633238, -2.455863]],
#    ('_7', '_8'): [1, [0.633238, 0.68573]],
#    ('_8', '_7'): [1, [-0.633238, -2.455863]],
#    ('_8', '_9'): [1, [0.948683, 1.249046]],
#    ('_9', '_8'): [1, [-0.948683, -1.892547]],
#    ('_9', '_2'): [1, [0.4741, 0.493941]],
#    ('_2', '_9'): [1, [-0.4741, -2.647651]],
#    ('_3', '_4'): [1, [1.0, 1.570796]],
#    ('_4', '_3'): [1, [-1.0, -1.570796]]},
#   'L',
#   'Normal graph'),
#  (304,
#   {'_1': [147.0, 125.0], '_2': [150.0, 160.0], '_3': [156.0, 141.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.871576, 1.058407]],
#    ('_3', '_1'): [1, [-0.871576, -2.083186]],
#    ('_3', '_2'): [1, [0.953583, 1.876675]],
#    ('_2', '_3'): [1, [-0.953583, -1.264917]]},
#   'L',
#   'Normal graph'),
#  (305,
#   {'_1': [158.0, 119.0],
#    '_2': [197.0, 168.0],
#    '_3': [167.0, 131.0],
#    '_4': [179.0, 141.0],
#    '_5': [190.0, 153.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [0.8, 0.927295]],
#    ('_3', '_1'): [1, [-0.8, -2.214297]],
#    ('_3', '_4'): [1, [0.640184, 0.694738]],
#    ('_4', '_3'): [1, [-0.640184, -2.446854]],
#    ('_4', '_5'): [1, [0.737154, 0.828849]],
#    ('_5', '_4'): [1, [-0.737154, -2.312744]],
#    ('_5', '_2'): [1, [0.906183, 1.134169]],
#    ('_2', '_5'): [1, [-0.906183, -2.007423]]},
#   'L',
#   'Normal graph'),
#  (306,
#   {'_1': [221.0, 79.0],
#    '_2': [146.0, 101.0],
#    '_3': [69.0, 106.0],
#    '_4': [48.0, 151.0],
#    '_5': [219.0, 90.0],
#    '_6': [209.0, 100.0],
#    '_7': [203.0, 115.0],
#    '_8': [185.0, 118.0],
#    '_9': [167.0, 121.0],
#    '_10': [157.0, 111.0],
#    '_11': [77.0, 120.0],
#    '_12': [64.0, 120.0],
#    '_13': [51.0, 129.0],
#    '_14': [60.0, 141.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_10')], [('_10', '_2')]),
#                '_3': ([('_3', '_11')], [('_11', '_3')]),
#                '_4': ([('_4', '_14')], [('_14', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_10')],
#                 [('_8', '_9'), ('_10', '_9')]),
#                '_10': ([('_10', '_9'), ('_10', '_2')],
#                 [('_9', '_10'), ('_2', '_10')]),
#                '_11': ([('_11', '_3'), ('_11', '_12')],
#                 [('_3', '_11'), ('_12', '_11')]),
#                '_12': ([('_12', '_11'), ('_12', '_13')],
#                 [('_11', '_12'), ('_13', '_12')]),
#                '_13': ([('_13', '_12'), ('_13', '_14')],
#                 [('_12', '_13'), ('_14', '_13')]),
#                '_14': ([('_14', '_13'), ('_14', '_4')],
#                 [('_13', '_14'), ('_4', '_14')])}),
#   {('_1', '_5'): [1, [0.98387, 1.75065]],
#    ('_5', '_1'): [1, [-0.98387, -1.390943]],
#    ('_5', '_6'): [1, [0.707107, 2.356194]],
#    ('_6', '_5'): [1, [-0.707107, -0.785398]],
#    ('_6', '_7'): [1, [0.928477, 1.951303]],
#    ('_7', '_6'): [1, [-0.928477, -1.19029]],
#    ('_7', '_8'): [1, [0.164399, 2.976444]],
#    ('_8', '_7'): [1, [-0.164399, -0.165149]],
#    ('_8', '_9'): [1, [0.164399, 2.976444]],
#    ('_9', '_8'): [1, [-0.164399, -0.165149]],
#    ('_9', '_10'): [1, [-0.707107, -2.356194]],
#    ('_10', '_9'): [1, [0.707107, 0.785398]],
#    ('_10', '_2'): [1, [-0.672673, -2.403778]],
#    ('_2', '_10'): [1, [0.672673, 0.737815]],
#    ('_3', '_11'): [1, [0.868243, 1.05165]],
#    ('_11', '_3'): [1, [-0.868243, -2.089942]],
#    ('_11', '_12'): [1, [0.0, 3.141593]],
#    ('_12', '_11'): [1, [0.0, 0.0]],
#    ('_12', '_13'): [1, [0.56921, 2.536048]],
#    ('_13', '_12'): [1, [-0.56921, -0.605545]],
#    ('_13', '_14'): [1, [0.8, 0.927295]],
#    ('_14', '_13'): [1, [-0.8, -2.214297]],
#    ('_14', '_4'): [1, [0.640184, 2.446854]],
#    ('_4', '_14'): [1, [-0.640184, -0.694738]]},
#   'L',
#   'Normal graph'),
#  (307,
#   {'_1': [155.0, 98.0],
#    '_2': [212.0, 167.0],
#    '_3': [169.0, 104.0],
#    '_4': [186.0, 109.0],
#    '_5': [196.0, 121.0],
#    '_6': [205.0, 134.0],
#    '_7': [210.0, 151.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.393919, 0.404892]],
#    ('_3', '_1'): [1, [-0.393919, -2.736701]],
#    ('_3', '_4'): [1, [0.282166, 0.286051]],
#    ('_4', '_3'): [1, [-0.282166, -2.855541]],
#    ('_4', '_5'): [1, [0.768221, 0.876058]],
#    ('_5', '_4'): [1, [-0.768221, -2.265535]],
#    ('_5', '_6'): [1, [0.822192, 0.965252]],
#    ('_6', '_5'): [1, [-0.822192, -2.176341]],
#    ('_6', '_7'): [1, [0.959366, 1.284745]],
#    ('_7', '_6'): [1, [-0.959366, -1.856848]],
#    ('_7', '_2'): [1, [0.992278, 1.446441]],
#    ('_2', '_7'): [1, [-0.992278, -1.695151]]},
#   'L',
#   'Normal graph'),
#  (308,
#   {'_1': [130.0, 110.0], '_2': [136.0, 134.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.970143, 1.325818]],
#    ('_2', '_1'): [1, [-0.970143, -1.815775]]},
#   'L',
#   'Normal graph'),
#  (309,
#   {'_1': [189.0, 131.0], '_2': [188.0, 143.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.996546, 1.653938]],
#    ('_2', '_1'): [1, [-0.996546, -1.487655]]},
#   'L',
#   'Normal graph'),
#  (310,
#   {'_1': [132.0, 120.0],
#    '_2': [186.0, 154.0],
#    '_3': [148.0, 125.0],
#    '_4': [165.0, 130.0],
#    '_5': [178.0, 140.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [0.298275, 0.302885]],
#    ('_3', '_1'): [1, [-0.298275, -2.838708]],
#    ('_3', '_4'): [1, [0.282166, 0.286051]],
#    ('_4', '_3'): [1, [-0.282166, -2.855541]],
#    ('_4', '_5'): [1, [0.609711, 0.655696]],
#    ('_5', '_4'): [1, [-0.609711, -2.485897]],
#    ('_5', '_2'): [1, [0.868243, 1.05165]],
#    ('_2', '_5'): [1, [-0.868243, -2.089942]]},
#   'L',
#   'Normal graph'),
#  (311,
#   {'_1': [172.0, 92.0], '_2': [175.0, 102.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.957826, 1.27934]],
#    ('_2', '_1'): [1, [-0.957826, -1.862253]]},
#   'L',
#   'Normal graph'),
#  (312,
#   {'_1': [82.0, 108.0], '_2': [79.0, 129.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.989949, 1.712693]],
#    ('_2', '_1'): [1, [-0.989949, -1.428899]]},
#   'L',
#   'Normal graph'),
#  (313, {}, defaultdict(list, {}), {}, 'L', 'Empty graph'),
#  (314,
#   {'_1': [120.0, 92.0],
#    '_2': [166.0, 153.0],
#    '_3': [130.0, 102.0],
#    '_4': [147.0, 107.0],
#    '_5': [157.0, 118.0],
#    '_6': [163.0, 134.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.707107, 0.785398]],
#    ('_3', '_1'): [1, [-0.707107, -2.356194]],
#    ('_3', '_4'): [1, [0.282166, 0.286051]],
#    ('_4', '_3'): [1, [-0.282166, -2.855541]],
#    ('_4', '_5'): [1, [0.73994, 0.832981]],
#    ('_5', '_4'): [1, [-0.73994, -2.308611]],
#    ('_5', '_6'): [1, [0.936329, 1.212026]],
#    ('_6', '_5'): [1, [-0.936329, -1.929567]],
#    ('_6', '_2'): [1, [0.987763, 1.414194]],
#    ('_2', '_6'): [1, [-0.987763, -1.727398]]},
#   'L',
#   'Normal graph'),
#  (315,
#   {'_1': [137.0, 126.0],
#    '_2': [188.0, 186.0],
#    '_3': [153.0, 132.0],
#    '_4': [165.0, 142.0],
#    '_5': [177.0, 153.0],
#    '_6': [185.0, 167.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.351123, 0.358771]],
#    ('_3', '_1'): [1, [-0.351123, -2.782822]],
#    ('_3', '_4'): [1, [0.640184, 0.694738]],
#    ('_4', '_3'): [1, [-0.640184, -2.446854]],
#    ('_4', '_5'): [1, [0.675725, 0.741947]],
#    ('_5', '_4'): [1, [-0.675725, -2.399645]],
#    ('_5', '_6'): [1, [0.868243, 1.05165]],
#    ('_6', '_5'): [1, [-0.868243, -2.089942]],
#    ('_6', '_2'): [1, [0.987763, 1.414194]],
#    ('_2', '_6'): [1, [-0.987763, -1.727398]]},
#   'L',
#   'Normal graph'),
#  (316,
#   {'_1': [156.0, 157.0], '_2': [173.0, 173.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')])}),
#   {('_1', '_2'): [1, [0.685365, 0.755104]],
#    ('_2', '_1'): [1, [-0.685365, -2.386488]]},
#   'L',
#   'Normal graph'),
#  (317,
#   {'_1': [136.0, 94.0],
#    '_2': [170.0, 177.0],
#    '_3': [139.0, 115.0],
#    '_4': [151.0, 127.0],
#    '_5': [159.0, 142.0],
#    '_6': [164.0, 161.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.989949, 1.428899]],
#    ('_3', '_1'): [1, [-0.989949, -1.712693]],
#    ('_3', '_4'): [1, [0.707107, 0.785398]],
#    ('_4', '_3'): [1, [-0.707107, -2.356194]],
#    ('_4', '_5'): [1, [0.882353, 1.080839]],
#    ('_5', '_4'): [1, [-0.882353, -2.060754]],
#    ('_5', '_6'): [1, [0.967075, 1.313473]],
#    ('_6', '_5'): [1, [-0.967075, -1.82812]],
#    ('_6', '_2'): [1, [0.936329, 1.212026]],
#    ('_2', '_6'): [1, [-0.936329, -1.929567]]},
#   'L',
#   'Normal graph'),
#  (318,
#   {'_1': [143.0, 129.0],
#    '_2': [184.0, 187.0],
#    '_3': [154.0, 143.0],
#    '_4': [167.0, 155.0],
#    '_5': [178.0, 168.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [0.786318, 0.904827]],
#    ('_3', '_1'): [1, [-0.786318, -2.236766]],
#    ('_3', '_4'): [1, [0.67828, 0.745419]],
#    ('_4', '_3'): [1, [-0.67828, -2.396173]],
#    ('_4', '_5'): [1, [0.763386, 0.868539]],
#    ('_5', '_4'): [1, [-0.763386, -2.273053]],
#    ('_5', '_2'): [1, [0.953583, 1.264917]],
#    ('_2', '_5'): [1, [-0.953583, -1.876675]]},
#   'L',
#   'Normal graph'),
#  (319,
#   {'_1': [133.0, 152.0], '_2': [162.0, 176.0], '_3': [145.0, 166.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.759257, 0.86217]],
#    ('_3', '_1'): [1, [-0.759257, -2.279423]],
#    ('_3', '_2'): [1, [0.50702, 0.531724]],
#    ('_2', '_3'): [1, [-0.50702, -2.609869]]},
#   'L',
#   'Normal graph'),
#  (320,
#   {'_1': [134.0, 65.0],
#    '_2': [178.0, 184.0],
#    '_3': [132.0, 80.0],
#    '_4': [125.0, 94.0],
#    '_5': [127.0, 111.0],
#    '_6': [134.0, 125.0],
#    '_7': [141.0, 139.0],
#    '_8': [151.0, 150.0],
#    '_9': [161.0, 161.0],
#    '_10': [172.0, 171.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_10')], [('_10', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_10')],
#                 [('_8', '_9'), ('_10', '_9')]),
#                '_10': ([('_10', '_9'), ('_10', '_2')],
#                 [('_9', '_10'), ('_2', '_10')])}),
#   {('_1', '_3'): [1, [0.991228, 1.703348]],
#    ('_3', '_1'): [1, [-0.991228, -1.438245]],
#    ('_3', '_4'): [1, [0.894427, 2.034444]],
#    ('_4', '_3'): [1, [-0.894427, -1.107149]],
#    ('_4', '_5'): [1, [0.993151, 1.453688]],
#    ('_5', '_4'): [1, [-0.993151, -1.687905]],
#    ('_5', '_6'): [1, [0.894427, 1.107149]],
#    ('_6', '_5'): [1, [-0.894427, -2.034444]],
#    ('_6', '_7'): [1, [0.894427, 1.107149]],
#    ('_7', '_6'): [1, [-0.894427, -2.034444]],
#    ('_7', '_8'): [1, [0.73994, 0.832981]],
#    ('_8', '_7'): [1, [-0.73994, -2.308611]],
#    ('_8', '_9'): [1, [0.73994, 0.832981]],
#    ('_9', '_8'): [1, [-0.73994, -2.308611]],
#    ('_9', '_10'): [1, [0.672673, 0.737815]],
#    ('_10', '_9'): [1, [-0.672673, -2.403778]],
#    ('_10', '_2'): [1, [0.907959, 1.138389]],
#    ('_2', '_10'): [1, [-0.907959, -2.003204]]},
#   'L',
#   'Normal graph'),
#  (321,
#   {'_1': [135.0, 94.0],
#    '_2': [182.0, 174.0],
#    '_3': [144.0, 107.0],
#    '_4': [158.0, 115.0],
#    '_5': [173.0, 123.0],
#    '_6': [171.0, 141.0],
#    '_7': [178.0, 156.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.822192, 0.965252]],
#    ('_3', '_1'): [1, [-0.822192, -2.176341]],
#    ('_3', '_4'): [1, [0.496139, 0.519146]],
#    ('_4', '_3'): [1, [-0.496139, -2.622447]],
#    ('_4', '_5'): [1, [0.470588, 0.489957]],
#    ('_5', '_4'): [1, [-0.470588, -2.651635]],
#    ('_5', '_6'): [1, [0.993884, 1.681454]],
#    ('_6', '_5'): [1, [-0.993884, -1.460139]],
#    ('_6', '_7'): [1, [0.906183, 1.134169]],
#    ('_7', '_6'): [1, [-0.906183, -2.007423]],
#    ('_7', '_2'): [1, [0.976187, 1.352127]],
#    ('_2', '_7'): [1, [-0.976187, -1.789465]]},
#   'L',
#   'Normal graph'),
#  (322, {}, defaultdict(list, {}), {}, 'L', 'Empty graph'),
#  (323,
#   {'_1': [51.0, 112.0],
#    '_2': [70.0, 164.0],
#    '_3': [38.0, 174.0],
#    '_4': [46.0, 205.0],
#    '_5': [56.0, 128.0],
#    '_6': [67.0, 139.0],
#    '_7': [76.0, 151.0],
#    '_8': [36.0, 191.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_8')], [('_8', '_3')]),
#                '_4': ([('_4', '_8')], [('_8', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')]),
#                '_8': ([('_8', '_3'), ('_8', '_4')],
#                 [('_3', '_8'), ('_4', '_8')])}),
#   {('_1', '_5'): [1, [0.95448, 1.267911]],
#    ('_5', '_1'): [1, [-0.95448, -1.873681]],
#    ('_5', '_6'): [1, [0.707107, 0.785398]],
#    ('_6', '_5'): [1, [-0.707107, -2.356194]],
#    ('_6', '_7'): [1, [0.8, 0.927295]],
#    ('_7', '_6'): [1, [-0.8, -2.214297]],
#    ('_7', '_2'): [1, [0.907959, 2.003204]],
#    ('_2', '_7'): [1, [-0.907959, -1.138389]],
#    ('_3', '_8'): [1, [0.993151, 1.687905]],
#    ('_8', '_3'): [1, [-0.993151, -1.453688]],
#    ('_8', '_4'): [1, [0.813733, 0.950547]],
#    ('_4', '_8'): [1, [-0.813733, -2.191046]]},
#   'L',
#   'Normal graph'),
#  (324,
#   {'_1': [168.0, 117.0],
#    '_2': [191.0, 207.0],
#    '_3': [178.0, 127.0],
#    '_4': [191.0, 135.0],
#    '_5': [196.0, 148.0],
#    '_6': [204.0, 161.0],
#    '_7': [201.0, 176.0],
#    '_8': [192.0, 188.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_8')], [('_8', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_2')],
#                 [('_7', '_8'), ('_2', '_8')])}),
#   {('_1', '_3'): [1, [0.707107, 0.785398]],
#    ('_3', '_1'): [1, [-0.707107, -2.356194]],
#    ('_3', '_4'): [1, [0.524097, 0.551655]],
#    ('_4', '_3'): [1, [-0.524097, -2.589938]],
#    ('_4', '_5'): [1, [0.933346, 1.203622]],
#    ('_5', '_4'): [1, [-0.933346, -1.93797]],
#    ('_5', '_6'): [1, [0.851658, 1.019141]],
#    ('_6', '_5'): [1, [-0.851658, -2.122451]],
#    ('_6', '_7'): [1, [0.980581, 1.768192]],
#    ('_7', '_6'): [1, [-0.980581, -1.373401]],
#    ('_7', '_8'): [1, [0.8, 2.214297]],
#    ('_8', '_7'): [1, [-0.8, -0.927295]],
#    ('_8', '_2'): [1, [0.998618, 1.623379]],
#    ('_2', '_8'): [1, [-0.998618, -1.518213]]},
#   'L',
#   'Normal graph'),
#  (325,
#   {'_1': [97.0, 131.0], '_2': [132.0, 153.0], '_3': [115.0, 142.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.52145, 0.548549]],
#    ('_3', '_1'): [1, [-0.52145, -2.593043]],
#    ('_3', '_2'): [1, [0.543251, 0.574305]],
#    ('_2', '_3'): [1, [-0.543251, -2.567288]]},
#   'L',
#   'Normal graph'),
#  (326,
#   {'_1': [30.0, 85.0],
#    '_2': [202.0, 187.0],
#    '_3': [37.0, 99.0],
#    '_4': [42.0, 113.0],
#    '_5': [50.0, 126.0],
#    '_6': [61.0, 137.0],
#    '_7': [73.0, 134.0],
#    '_8': [88.0, 136.0],
#    '_9': [103.0, 142.0],
#    '_10': [111.0, 155.0],
#    '_11': [127.0, 158.0],
#    '_12': [129.0, 147.0],
#    '_13': [146.0, 145.0],
#    '_14': [159.0, 154.0],
#    '_15': [170.0, 164.0],
#    '_16': [181.0, 174.0],
#    '_17': [191.0, 185.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_17')], [('_17', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_10')],
#                 [('_8', '_9'), ('_10', '_9')]),
#                '_10': ([('_10', '_9'), ('_10', '_11')],
#                 [('_9', '_10'), ('_11', '_10')]),
#                '_11': ([('_11', '_10'), ('_11', '_12')],
#                 [('_10', '_11'), ('_12', '_11')]),
#                '_12': ([('_12', '_11'), ('_12', '_13')],
#                 [('_11', '_12'), ('_13', '_12')]),
#                '_13': ([('_13', '_12'), ('_13', '_14')],
#                 [('_12', '_13'), ('_14', '_13')]),
#                '_14': ([('_14', '_13'), ('_14', '_15')],
#                 [('_13', '_14'), ('_15', '_14')]),
#                '_15': ([('_15', '_14'), ('_15', '_16')],
#                 [('_14', '_15'), ('_16', '_15')]),
#                '_16': ([('_16', '_15'), ('_16', '_17')],
#                 [('_15', '_16'), ('_17', '_16')]),
#                '_17': ([('_17', '_16'), ('_17', '_2')],
#                 [('_16', '_17'), ('_2', '_17')])}),
#   {('_1', '_3'): [1, [0.894427, 1.107149]],
#    ('_3', '_1'): [1, [-0.894427, -2.034444]],
#    ('_3', '_4'): [1, [0.941742, 1.227772]],
#    ('_4', '_3'): [1, [-0.941742, -1.91382]],
#    ('_4', '_5'): [1, [0.851658, 1.019141]],
#    ('_5', '_4'): [1, [-0.851658, -2.122451]],
#    ('_5', '_6'): [1, [0.707107, 0.785398]],
#    ('_6', '_5'): [1, [-0.707107, -2.356194]],
#    ('_6', '_7'): [1, [-0.242536, -0.244979]],
#    ('_7', '_6'): [1, [0.242536, 2.896614]],
#    ('_7', '_8'): [1, [0.132164, 0.132552]],
#    ('_8', '_7'): [1, [-0.132164, -3.009041]],
#    ('_8', '_9'): [1, [0.371391, 0.380506]],
#    ('_9', '_8'): [1, [-0.371391, -2.761086]],
#    ('_9', '_10'): [1, [0.851658, 1.019141]],
#    ('_10', '_9'): [1, [-0.851658, -2.122451]],
#    ('_10', '_11'): [1, [0.184289, 0.185348]],
#    ('_11', '_10'): [1, [-0.184289, -2.956245]],
#    ('_11', '_12'): [1, [-0.98387, -1.390943]],
#    ('_12', '_11'): [1, [0.98387, 1.75065]],
#    ('_12', '_13'): [1, [-0.116841, -0.117109]],
#    ('_13', '_12'): [1, [0.116841, 3.024484]],
#    ('_13', '_14'): [1, [0.56921, 0.605545]],
#    ('_14', '_13'): [1, [-0.56921, -2.536048]],
#    ('_14', '_15'): [1, [0.672673, 0.737815]],
#    ('_15', '_14'): [1, [-0.672673, -2.403778]],
#    ('_15', '_16'): [1, [0.672673, 0.737815]],
#    ('_16', '_15'): [1, [-0.672673, -2.403778]],
#    ('_16', '_17'): [1, [0.73994, 0.832981]],
#    ('_17', '_16'): [1, [-0.73994, -2.308611]],
#    ('_17', '_2'): [1, [0.178885, 0.179853]],
#    ('_2', '_17'): [1, [-0.178885, -2.961739]]},
#   'L',
#   'Normal graph'),
#  (327,
#   {'_1': [119.0, 145.0],
#    '_2': [134.0, 193.0],
#    '_3': [126.0, 159.0],
#    '_4': [132.0, 174.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_4')], [('_4', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_2')],
#                 [('_3', '_4'), ('_2', '_4')])}),
#   {('_1', '_3'): [1, [0.894427, 1.107149]],
#    ('_3', '_1'): [1, [-0.894427, -2.034444]],
#    ('_3', '_4'): [1, [0.928477, 1.19029]],
#    ('_4', '_3'): [1, [-0.928477, -1.951303]],
#    ('_4', '_2'): [1, [0.994505, 1.465919]],
#    ('_2', '_4'): [1, [-0.994505, -1.675673]]},
#   'L',
#   'Normal graph'),
#  (328,
#   {'_1': [97.0, 99.0],
#    '_2': [148.0, 154.0],
#    '_3': [108.0, 109.0],
#    '_4': [123.0, 115.0],
#    '_5': [134.0, 126.0],
#    '_6': [143.0, 138.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_6')], [('_6', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_2')],
#                 [('_5', '_6'), ('_2', '_6')])}),
#   {('_1', '_3'): [1, [0.672673, 0.737815]],
#    ('_3', '_1'): [1, [-0.672673, -2.403778]],
#    ('_3', '_4'): [1, [0.371391, 0.380506]],
#    ('_4', '_3'): [1, [-0.371391, -2.761086]],
#    ('_4', '_5'): [1, [0.707107, 0.785398]],
#    ('_5', '_4'): [1, [-0.707107, -2.356194]],
#    ('_5', '_6'): [1, [0.8, 0.927295]],
#    ('_6', '_5'): [1, [-0.8, -2.214297]],
#    ('_6', '_2'): [1, [0.95448, 1.267911]],
#    ('_2', '_6'): [1, [-0.95448, -1.873681]]},
#   'L',
#   'Normal graph'),
#  (329,
#   {'_1': [94.0, 123.0],
#    '_2': [185.0, 159.0],
#    '_3': [103.0, 135.0],
#    '_4': [117.0, 142.0],
#    '_5': [133.0, 148.0],
#    '_6': [150.0, 152.0],
#    '_7': [167.0, 156.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.8, 0.927295]],
#    ('_3', '_1'): [1, [-0.8, -2.214297]],
#    ('_3', '_4'): [1, [0.447214, 0.463648]],
#    ('_4', '_3'): [1, [-0.447214, -2.677945]],
#    ('_4', '_5'): [1, [0.351123, 0.358771]],
#    ('_5', '_4'): [1, [-0.351123, -2.782822]],
#    ('_5', '_6'): [1, [0.229039, 0.231091]],
#    ('_6', '_5'): [1, [-0.229039, -2.910502]],
#    ('_6', '_7'): [1, [0.229039, 0.231091]],
#    ('_7', '_6'): [1, [-0.229039, -2.910502]],
#    ('_7', '_2'): [1, [0.164399, 0.165149]],
#    ('_2', '_7'): [1, [-0.164399, -2.976444]]},
#   'L',
#   'Normal graph'),
#  (330,
#   {'_1': [137.0, 113.0], '_2': [149.0, 150.0], '_3': [145.0, 130.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.904819, 1.130954]],
#    ('_3', '_1'): [1, [-0.904819, -2.010639]],
#    ('_3', '_2'): [1, [0.980581, 1.373401]],
#    ('_2', '_3'): [1, [-0.980581, -1.768192]]},
#   'L',
#   'Normal graph'),
#  (331,
#   {'_1': [126.0, 97.0], '_2': [143.0, 128.0], '_3': [137.0, 110.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.763386, 0.868539]],
#    ('_3', '_1'): [1, [-0.763386, -2.273053]],
#    ('_3', '_2'): [1, [0.948683, 1.249046]],
#    ('_2', '_3'): [1, [-0.948683, -1.892547]]},
#   'L',
#   'Normal graph'),
#  (332,
#   {'_1': [219.0, 123.0],
#    '_2': [160.0, 164.0],
#    '_3': [217.0, 132.0],
#    '_4': [204.0, 140.0],
#    '_5': [201.0, 154.0],
#    '_6': [198.0, 166.0],
#    '_7': [179.0, 164.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.976187, 1.789465]],
#    ('_3', '_1'): [1, [-0.976187, -1.352127]],
#    ('_3', '_4'): [1, [0.524097, 2.589938]],
#    ('_4', '_3'): [1, [-0.524097, -0.551655]],
#    ('_4', '_5'): [1, [0.977802, 1.78189]],
#    ('_5', '_4'): [1, [-0.977802, -1.359703]],
#    ('_5', '_6'): [1, [0.970143, 1.815775]],
#    ('_6', '_5'): [1, [-0.970143, -1.325818]],
#    ('_6', '_7'): [1, [-0.104685, -3.036716]],
#    ('_7', '_6'): [1, [0.104685, 0.104877]],
#    ('_7', '_2'): [1, [0.0, 3.141593]],
#    ('_2', '_7'): [1, [0.0, 0.0]]},
#   'L',
#   'Normal graph'),
#  (333,
#   {'_1': [146.0, 92.0],
#    '_2': [201.0, 161.0],
#    '_3': [155.0, 104.0],
#    '_4': [166.0, 114.0],
#    '_5': [178.0, 123.0],
#    '_6': [187.0, 135.0],
#    '_7': [196.0, 147.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.8, 0.927295]],
#    ('_3', '_1'): [1, [-0.8, -2.214297]],
#    ('_3', '_4'): [1, [0.672673, 0.737815]],
#    ('_4', '_3'): [1, [-0.672673, -2.403778]],
#    ('_4', '_5'): [1, [0.6, 0.643501]],
#    ('_5', '_4'): [1, [-0.6, -2.498092]],
#    ('_5', '_6'): [1, [0.8, 0.927295]],
#    ('_6', '_5'): [1, [-0.8, -2.214297]],
#    ('_6', '_7'): [1, [0.8, 0.927295]],
#    ('_7', '_6'): [1, [-0.8, -2.214297]],
#    ('_7', '_2'): [1, [0.941742, 1.227772]],
#    ('_2', '_7'): [1, [-0.941742, -1.91382]]},
#   'L',
#   'Normal graph'),
#  (334,
#   {'_1': [147.0, 102.0],
#    '_2': [122.0, 118.0],
#    '_3': [107.0, 148.0],
#    '_4': [215.0, 169.0],
#    '_5': [156.0, 116.0],
#    '_6': [170.0, 124.0],
#    '_7': [184.0, 133.0],
#    '_8': [196.0, 143.0],
#    '_9': [207.0, 155.0],
#    '_10': [116.0, 135.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_10')], [('_10', '_2')]),
#                '_3': ([('_3', '_10')], [('_10', '_3')]),
# ...
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [-0.21693, -0.218669]],
#    ('_3', '_1'): [1, [0.21693, 2.922924]],
#    ('_3', '_4'): [1, [0.813733, 0.950547]],
#    ('_4', '_3'): [1, [-0.813733, -2.191046]],
#    ('_4', '_5'): [1, [0.916157, 1.158386]],
#    ('_5', '_4'): [1, [-0.916157, -1.983207]],
#    ('_5', '_2'): [1, [0.980581, 1.768192]],
#    ('_2', '_5'): [1, [-0.980581, -1.373401]]},
#   'L',
#   'Normal graph'),
#  (394,
#   {'_1': [126.0, 103.0],
#    '_2': [193.0, 171.0],
#    '_3': [136.0, 116.0],
#    '_4': [148.0, 126.0],
#    '_5': [160.0, 137.0],
#    '_6': [172.0, 147.0],
#    '_7': [183.0, 159.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.792624, 0.915101]],
#    ('_3', '_1'): [1, [-0.792624, -2.226492]],
#    ('_3', '_4'): [1, [0.640184, 0.694738]],
#    ('_4', '_3'): [1, [-0.640184, -2.446854]],
#    ('_4', '_5'): [1, [0.675725, 0.741947]],
#    ('_5', '_4'): [1, [-0.675725, -2.399645]],
#    ('_5', '_6'): [1, [0.640184, 0.694738]],
#    ('_6', '_5'): [1, [-0.640184, -2.446854]],
#    ('_6', '_7'): [1, [0.737154, 0.828849]],
#    ('_7', '_6'): [1, [-0.737154, -2.312744]],
#    ('_7', '_2'): [1, [0.768221, 0.876058]],
#    ('_2', '_7'): [1, [-0.768221, -2.265535]]},
#   'L',
#   'Normal graph'),
#  (395,
#   {'_1': [146.0, 90.0],
#    '_2': [205.0, 169.0],
#    '_3': [159.0, 100.0],
#    '_4': [174.0, 108.0],
#    '_5': [188.0, 117.0],
#    '_6': [199.0, 129.0],
#    '_7': [202.0, 149.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_2')],
#                 [('_6', '_7'), ('_2', '_7')])}),
#   {('_1', '_3'): [1, [0.609711, 0.655696]],
#    ('_3', '_1'): [1, [-0.609711, -2.485897]],
#    ('_3', '_4'): [1, [0.470588, 0.489957]],
#    ('_4', '_3'): [1, [-0.470588, -2.651635]],
#    ('_4', '_5'): [1, [0.540758, 0.571337]],
#    ('_5', '_4'): [1, [-0.540758, -2.570255]],
#    ('_5', '_6'): [1, [0.737154, 0.828849]],
#    ('_6', '_5'): [1, [-0.737154, -2.312744]],
#    ('_6', '_7'): [1, [0.988936, 1.421906]],
#    ('_7', '_6'): [1, [-0.988936, -1.719686]],
#    ('_7', '_2'): [1, [0.988936, 1.421906]],
#    ('_2', '_7'): [1, [-0.988936, -1.719686]]},
#   'L',
#   'Normal graph'),
#  (396, {}, defaultdict(list, {}), {}, 'L', 'Empty graph'),
#  (397,
#   {'_1': [134.0, 109.0], '_2': [150.0, 140.0], '_3': [144.0, 123.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.813733, 0.950547]],
#    ('_3', '_1'): [1, [-0.813733, -2.191046]],
#    ('_3', '_2'): [1, [0.94299, 1.231504]],
#    ('_2', '_3'): [1, [-0.94299, -1.910089]]},
#   'L',
#   'Normal graph'),
#  (398,
#   {'_1': [144.0, 78.0],
#    '_2': [192.0, 196.0],
#    '_3': [157.0, 84.0],
#    '_4': [172.0, 90.0],
#    '_5': [185.0, 98.0],
#    '_6': [191.0, 113.0],
#    '_7': [196.0, 128.0],
#    '_8': [202.0, 143.0],
#    '_9': [198.0, 160.0],
#    '_10': [195.0, 178.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_10')], [('_10', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_10')],
#                 [('_8', '_9'), ('_10', '_9')]),
#                '_10': ([('_10', '_9'), ('_10', '_2')],
#                 [('_9', '_10'), ('_2', '_10')])}),
#   {('_1', '_3'): [1, [0.419058, 0.432408]],
#    ('_3', '_1'): [1, [-0.419058, -2.709185]],
#    ('_3', '_4'): [1, [0.371391, 0.380506]],
#    ('_4', '_3'): [1, [-0.371391, -2.761086]],
#    ('_4', '_5'): [1, [0.524097, 0.551655]],
#    ('_5', '_4'): [1, [-0.524097, -2.589938]],
#    ('_5', '_6'): [1, [0.928477, 1.19029]],
#    ('_6', '_5'): [1, [-0.928477, -1.951303]],
#    ('_6', '_7'): [1, [0.948683, 1.249046]],
#    ('_7', '_6'): [1, [-0.948683, -1.892547]],
#    ('_7', '_8'): [1, [0.928477, 1.19029]],
#    ('_8', '_7'): [1, [-0.928477, -1.951303]],
#    ('_8', '_9'): [1, [0.973417, 1.801887]],
#    ('_9', '_8'): [1, [-0.973417, -1.339706]],
#    ('_9', '_10'): [1, [0.986394, 1.735945]],
#    ('_10', '_9'): [1, [-0.986394, -1.405648]],
#    ('_10', '_2'): [1, [0.986394, 1.735945]],
#    ('_2', '_10'): [1, [-0.986394, -1.405648]]},
#   'L',
#   'Normal graph'),
#  (399,
#   {'_1': [121.0, 135.0],
#    '_2': [138.0, 175.0],
#    '_3': [49.0, 182.0],
#    '_4': [59.0, 197.0],
#    '_5': [132.0, 154.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_4')], [('_4', '_3')]),
#                '_4': ([('_4', '_3')], [('_3', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_2')],
#                 [('_1', '_5'), ('_2', '_5')])}),
#   {('_1', '_5'): [1, [0.865426, 1.046001]],
#    ('_5', '_1'): [1, [-0.865426, -2.095592]],
#    ('_5', '_2'): [1, [0.961524, 1.292497]],
#    ('_2', '_5'): [1, [-0.961524, -1.849096]],
#    ('_3', '_4'): [1, [0.83205, 0.982794]],
#    ('_4', '_3'): [1, [-0.83205, -2.158799]]},
#   'L',
#   'Normal graph'),
#  (400,
#   {'_1': [110.0, 99.0],
#    '_2': [135.0, 117.0],
#    '_3': [120.0, 129.0],
#    '_4': [177.0, 190.0],
#    '_5': [119.0, 118.0],
#    '_6': [132.0, 137.0],
#    '_7': [141.0, 149.0],
#    '_8': [147.0, 161.0],
#    '_9': [163.0, 165.0],
#    '_10': [172.0, 177.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_6')], [('_6', '_3')]),
#                '_4': ([('_4', '_10')], [('_10', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_2')],
#                 [('_1', '_5'), ('_2', '_5')]),
#                '_6': ([('_6', '_3'), ('_6', '_7')],
#                 [('_3', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_10')],
#                 [('_8', '_9'), ('_10', '_9')]),
#                '_10': ([('_10', '_9'), ('_10', '_4')],
#                 [('_9', '_10'), ('_4', '_10')])}),
#   {('_1', '_5'): [1, [0.903738, 1.128422]],
#    ('_5', '_1'): [1, [-0.903738, -2.013171]],
#    ('_5', '_2'): [1, [-0.062378, -0.062419]],
#    ('_2', '_5'): [1, [0.062378, 3.079174]],
#    ('_3', '_6'): [1, [0.5547, 0.588003]],
#    ('_6', '_3'): [1, [-0.5547, -2.55359]],
#    ('_6', '_7'): [1, [0.8, 0.927295]],
#    ('_7', '_6'): [1, [-0.8, -2.214297]],
#    ('_7', '_8'): [1, [0.894427, 1.107149]],
#    ('_8', '_7'): [1, [-0.894427, -2.034444]],
#    ('_8', '_9'): [1, [0.242536, 0.244979]],
#    ('_9', '_8'): [1, [-0.242536, -2.896614]],
#    ('_9', '_10'): [1, [0.8, 0.927295]],
#    ('_10', '_9'): [1, [-0.8, -2.214297]],
#    ('_10', '_4'): [1, [0.933346, 1.203622]],
#    ('_4', '_10'): [1, [-0.933346, -1.93797]]},
#   'L',
#   'Normal graph'),
#  (401,
#   {'_1': [66.0, 86.0],
#    '_2': [121.0, 98.0],
#    '_3': [64.0, 128.0],
#    '_4': [140.0, 144.0],
#    '_5': [77.0, 100.0],
#    '_6': [78.0, 117.0],
#    '_7': [130.0, 111.0],
#    '_8': [135.0, 127.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_6')], [('_6', '_3')]),
#                '_4': ([('_4', '_8')], [('_8', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_3')],
#                 [('_5', '_6'), ('_3', '_6')]),
#                '_7': ([('_7', '_2'), ('_7', '_8')],
#                 [('_2', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_4')],
#                 [('_7', '_8'), ('_4', '_8')])}),
#   {('_1', '_5'): [1, [0.786318, 0.904827]],
#    ('_5', '_1'): [1, [-0.786318, -2.236766]],
#    ('_5', '_6'): [1, [0.998274, 1.512041]],
#    ('_6', '_5'): [1, [-0.998274, -1.629552]],
#    ('_6', '_3'): [1, [0.617822, 2.475623]],
#    ('_3', '_6'): [1, [-0.617822, -0.665969]],
#    ('_2', '_7'): [1, [0.822192, 0.965252]],
#    ('_7', '_2'): [1, [-0.822192, -2.176341]],
#    ('_7', '_8'): [1, [0.95448, 1.267911]],
#    ('_8', '_7'): [1, [-0.95448, -1.873681]],
#    ('_8', '_4'): [1, [0.959366, 1.284745]],
#    ('_4', '_8'): [1, [-0.959366, -1.856848]]},
#   'L',
#   'Normal graph'),
#  (402,
#   {'_1': [138.0, 99.0],
#    '_2': [175.0, 152.0],
#    '_3': [148.0, 111.0],
#    '_4': [161.0, 121.0],
#    '_5': [173.0, 133.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_5')], [('_5', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_2')],
#                 [('_4', '_5'), ('_2', '_5')])}),
#   {('_1', '_3'): [1, [0.768221, 0.876058]],
#    ('_3', '_1'): [1, [-0.768221, -2.265535]],
#    ('_3', '_4'): [1, [0.609711, 0.655696]],
#    ('_4', '_3'): [1, [-0.609711, -2.485897]],
#    ('_4', '_5'): [1, [0.707107, 0.785398]],
#    ('_5', '_4'): [1, [-0.707107, -2.356194]],
#    ('_5', '_2'): [1, [0.994505, 1.465919]],
#    ('_2', '_5'): [1, [-0.994505, -1.675673]]},
#   'L',
#   'Normal graph'),
#  (403,
#   {'_1': [94.0, 116.0],
#    '_2': [164.0, 192.0],
#    '_3': [103.0, 128.0],
#    '_4': [118.0, 134.0],
#    '_5': [131.0, 142.0],
#    '_6': [144.0, 151.0],
#    '_7': [155.0, 161.0],
#    '_8': [162.0, 175.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_8')], [('_8', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_4')],
#                 [('_1', '_3'), ('_4', '_3')]),
#                '_4': ([('_4', '_3'), ('_4', '_5')],
#                 [('_3', '_4'), ('_5', '_4')]),
#                '_5': ([('_5', '_4'), ('_5', '_6')],
#                 [('_4', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_7')],
#                 [('_5', '_6'), ('_7', '_6')]),
#                '_7': ([('_7', '_6'), ('_7', '_8')],
#                 [('_6', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_2')],
#                 [('_7', '_8'), ('_2', '_8')])}),
#   {('_1', '_3'): [1, [0.8, 0.927295]],
#    ('_3', '_1'): [1, [-0.8, -2.214297]],
#    ('_3', '_4'): [1, [0.371391, 0.380506]],
#    ('_4', '_3'): [1, [-0.371391, -2.761086]],
#    ('_4', '_5'): [1, [0.524097, 0.551655]],
#    ('_5', '_4'): [1, [-0.524097, -2.589938]],
#    ('_5', '_6'): [1, [0.56921, 0.605545]],
#    ('_6', '_5'): [1, [-0.56921, -2.536048]],
#    ('_6', '_7'): [1, [0.672673, 0.737815]],
#    ('_7', '_6'): [1, [-0.672673, -2.403778]],
#    ('_7', '_8'): [1, [0.894427, 1.107149]],
#    ('_8', '_7'): [1, [-0.894427, -2.034444]],
#    ('_8', '_2'): [1, [0.993151, 1.453688]],
#    ('_2', '_8'): [1, [-0.993151, -1.687905]]},
#   'L',
#   'Normal graph'),
#  (404,
#   {'_1': [74.0, 147.0],
#    '_2': [75.0, 162.0],
#    '_3': [134.0, 165.0],
#    '_4': [133.0, 187.0],
#    '_5': [141.0, 183.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_2')], [('_2', '_1')]),
#                '_2': ([('_2', '_1')], [('_1', '_2')]),
#                '_3': ([('_3', '_5')], [('_5', '_3')]),
#                '_4': ([('_4', '_5')], [('_5', '_4')]),
#                '_5': ([('_5', '_3'), ('_5', '_4')],
#                 [('_3', '_5'), ('_4', '_5')])}),
#   {('_1', '_2'): [1, [0.997785, 1.504228]],
#    ('_2', '_1'): [1, [-0.997785, -1.637364]],
#    ('_3', '_5'): [1, [0.932005, 1.199905]],
#    ('_5', '_3'): [1, [-0.932005, -1.941688]],
#    ('_5', '_4'): [1, [0.447214, 2.677945]],
#    ('_4', '_5'): [1, [-0.447214, -0.463648]]},
#   'L',
#   'Normal graph'),
#  (405,
#   {'_1': [142.0, 91.0], '_2': [152.0, 119.0], '_3': [149.0, 104.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.880471, 1.076855]],
#    ('_3', '_1'): [1, [-0.880471, -2.064738]],
#    ('_3', '_2'): [1, [0.980581, 1.373401]],
#    ('_2', '_3'): [1, [-0.980581, -1.768192]]},
#   'L',
#   'Normal graph'),
#  (406,
#   {'_1': [129.0, 101.0], '_2': [141.0, 142.0], '_3': [139.0, 120.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_3')], [('_3', '_1')]),
#                '_2': ([('_2', '_3')], [('_3', '_2')]),
#                '_3': ([('_3', '_1'), ('_3', '_2')],
#                 [('_1', '_3'), ('_2', '_3')])}),
#   {('_1', '_3'): [1, [0.884918, 1.086318]],
#    ('_3', '_1'): [1, [-0.884918, -2.055274]],
#    ('_3', '_2'): [1, [0.995893, 1.480136]],
#    ('_2', '_3'): [1, [-0.995893, -1.661456]]},
#   'L',
#   'Normal graph'),
#  (407,
#   {'_1': [43.0, 51.0],
#    '_2': [132.0, 81.0],
#    '_3': [30.0, 83.0],
#    '_4': [208.0, 122.0],
#    '_5': [31.0, 59.0],
#    '_6': [42.0, 71.0],
#    '_7': [143.0, 94.0],
#    '_8': [163.0, 98.0],
#    '_9': [184.0, 98.0],
#    '_10': [198.0, 108.0]},
#   defaultdict(list,
#               {'_1': ([('_1', '_5')], [('_5', '_1')]),
#                '_2': ([('_2', '_7')], [('_7', '_2')]),
#                '_3': ([('_3', '_6')], [('_6', '_3')]),
#                '_4': ([('_4', '_10')], [('_10', '_4')]),
#                '_5': ([('_5', '_1'), ('_5', '_6')],
#                 [('_1', '_5'), ('_6', '_5')]),
#                '_6': ([('_6', '_5'), ('_6', '_3')],
#                 [('_5', '_6'), ('_3', '_6')]),
#                '_7': ([('_7', '_2'), ('_7', '_8')],
#                 [('_2', '_7'), ('_8', '_7')]),
#                '_8': ([('_8', '_7'), ('_8', '_9')],
#                 [('_7', '_8'), ('_9', '_8')]),
#                '_9': ([('_9', '_8'), ('_9', '_10')],
#                 [('_8', '_9'), ('_10', '_9')]),
#                '_10': ([('_10', '_9'), ('_10', '_4')],
#                 [('_9', '_10'), ('_4', '_10')])}),
#   {('_1', '_5'): [1, [0.5547, 2.55359]],
#    ('_5', '_1'): [1, [-0.5547, -0.588003]],
#    ('_5', '_6'): [1, [0.737154, 0.828849]],
#    ('_6', '_5'): [1, [-0.737154, -2.312744]],
#    ('_6', '_3'): [1, [0.707107, 2.356194]],
#    ('_3', '_6'): [1, [-0.707107, -0.785398]],
#    ('_2', '_7'): [1, [0.763386, 0.868539]],
#    ('_7', '_2'): [1, [-0.763386, -2.273053]],
#    ('_7', '_8'): [1, [0.196116, 0.197396]],
#    ('_8', '_7'): [1, [-0.196116, -2.944197]],
#    ('_8', '_9'): [1, [0.0, 0.0]],
#    ('_9', '_8'): [1, [0.0, 3.141593]],
#    ('_9', '_10'): [1, [0.581238, 0.620249]],
#    ('_10', '_9'): [1, [-0.581238, -2.521343]],
#    ('_10', '_4'): [1, [0.813733, 0.950547]],
#    ('_4', '_10'): [1, [-0.813733, -2.191046]]},
#   'L',
#   'Normal graph')]
